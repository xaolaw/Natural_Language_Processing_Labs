# %% [markdown]
# # 1) Loading all required datasets

# %%
    from datasets import load_dataset

ds = load_dataset("clarin-knext/fiqa-pl", "corpus")
corpus = ds['corpus']
corpus
# Out:
# Dataset({
#     features: ['_id', 'title', 'text'],
#     num_rows: 57638
# })

# %%
ds = load_dataset("clarin-knext/fiqa-pl", "queries")
queries = ds['queries']
queries
# Out:
# Dataset({
#     features: ['_id', 'title', 'text'],
#     num_rows: 6648
# })

# %%
ds = load_dataset("clarin-knext/fiqa-pl-qrels")
train = ds['train']
validation = ds['validation']
test = ds['test']
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['query-id', 'corpus-id', 'score'],
#         num_rows: 14166
#     })
#     validation: Dataset({
#         features: ['query-id', 'corpus-id', 'score'],
#         num_rows: 1238
#     })
#     test: Dataset({
#         features: ['query-id', 'corpus-id', 'score'],
#         num_rows: 1706
#     })
# })

# %% [markdown]
# # 2) Use SpaCy tokenizer API to tokenize the text in the documents.

# %% [markdown]
# First let's import the nlp model

# %%
import spacy

nlp = spacy.load("pl_core_news_sm")
nlp

# %% [markdown]
# Now let's tokenize all documents and count occurances of all tokens per dataset

# %%
from collections import Counter

datasets = [corpus, queries]
frequency = [Counter(), Counter()]
index = 0

for ds in datasets:
  for item in ds:
    tokened_word = nlp(item['text'])
    for token in tokened_word:
      if not token.is_punct and not token.is_space:
        frequency[index][str(token.text.lower())] +=1
  index+=1
frequency[0]
# Out:
# Counter({'w': 175366,
#          'nie': 131482,
#          'i': 126839,
#          'na': 119047,
#          'to': 116468,
#          'z': 96953,
#          'jest': 93246,
#          'że': 90021,
#          'się': 85843,
#          'do': 66601,
#          'jeśli': 52003,
#          'ale': 41308,
#          'a': 41264,
#          'o': 38203,
#          'są': 35435,
#          'jak': 33672,
#          'lub': 33216,
#          'za': 32317,
#          'aby': 31053,
#          'od': 29829,
#          'co': 29702,
#          'może': 26370,
#          'po': 25715,
#          'tak': 25634,
#          'dla': 25462,
#          'które': 23983,
#          'możesz': 23280,
#          'tego': 21938,
#          'tym': 21608,
#          'czy': 20285,
#          'ma': 20284,
#          'być': 19267,
#          'ponieważ': 18957,
#          'przez': 17833,
#          'usd': 17524,
#          'tylko': 17262,
#          'więc': 17177,
#          'niż': 16827,
#          'ich': 14570,
#          'pieniądze': 13969,
#          'więcej': 13838,
#          'gdy': 13534,
#          'jako': 12980,
#          'pieniędzy': 12278,
#          'który': 12139,
#          'masz': 11710,
#          'będzie': 11694,
#          'mogą': 11679,
#          'firmy': 10725,
#          'również': 10531,
#          'akcji': 10417,
#          'bardzo': 10180,
#          'ci': 9984,
#          'prostu': 9782,
#          'nawet': 9727,
#          'lat': 9509,
#          '>': 9329,
#          'mają': 9298,
#          'wiele': 9223,
#          'ten': 8990,
#          'te': 8780,
#          'ze': 8616,
#          'kiedy': 8595,
#          'bez': 8281,
#          'akcje': 8117,
#          'teraz': 8101,
#          'roku': 8043,
#          'prawdopodobnie': 8038,
#          'jesteś': 7930,
#          'bardziej': 7780,
#          'przypadku': 7777,
#          'ludzie': 7757,
#          'naprawdę': 7744,
#          'która': 7677,
#          'dolarów': 7559,
#          'twoje': 7538,
#          'sposób': 7456,
#          'można': 7450,
#          '000': 7423,
#          'pracy': 7292,
#          '1': 7244,
#          'go': 7221,
#          'tych': 7172,
#          'sobie': 7158,
#          'musisz': 7098,
#          '10': 7044,
#          'będziesz': 6914,
#          'je': 6855,
#          'chcesz': 6825,
#          'tej': 6785,
#          'mieć': 6774,
#          'jednak': 6709,
#          'jestem': 6666,
#          'pod': 6612,
#          'już': 6518,
#          'twój': 6509,
#          'nadal': 6487,
#          'rzeczy': 6437,
#          'którzy': 6353,
#          'których': 6310,
#          'firma': 6284,
#          'wszystkie': 6248,
#          'kilka': 6223,
#          'będą': 6133,
#          'wartość': 5994,
#          'mniej': 5978,
#          'swoje': 5885,
#          'wszystko': 5790,
#          'rynku': 5765,
#          'ludzi': 5765,
#          'przed': 5705,
#          'stanie': 5704,
#          'wartości': 5644,
#          'oznacza': 5554,
#          'r': 5518,
#          'większość': 5510,
#          'mi': 5497,
#          '2': 5475,
#          'innych': 5448,
#          'coś': 5428,
#          'mam': 5320,
#          'usa': 5319,
#          'inne': 5307,
#          '100': 5267,
#          'było': 5263,
#          'zrobić': 5244,
#          'przykład': 5164,
#          'następnie': 5157,
#          'ceny': 5047,
#          'itp': 4987,
#          'takie': 4985,
#          'konto': 4985,
#          'jego': 4956,
#          'ile': 4955,
#          'przy': 4950,
#          'domu': 4940,
#          'czasu': 4917,
#          'którym': 4899,
#          'wielu': 4889,
#          'znacznie': 4851,
#          'myślę': 4744,
#          'nigdy': 4646,
#          'był': 4568,
#          'dlaczego': 4538,
#          'istnieje': 4528,
#          'nich': 4527,
#          'podatku': 4525,
#          'czas': 4516,
#          'swoich': 4482,
#          'cię': 4480,
#          '5': 4445,
#          'dużo': 4430,
#          'sprzedaży': 4408,
#          'około': 4399,
#          'mnie': 4398,
#          'dobrze': 4397,
#          'ciebie': 4396,
#          'konta': 4394,
#          '3': 4381,
#          'uzyskać': 4362,
#          'zawsze': 4327,
#          'wszystkich': 4179,
#          '=': 4177,
#          'podczas': 4151,
#          'cena': 4140,
#          'dlatego': 4135,
#          'którą': 4111,
#          'powinieneś': 4088,
#          'im': 4084,
#          'kredytu': 4056,
#          'osób': 4053,
#          'bank': 4012,
#          'też': 3990,
#          'ciągu': 3891,
#          'jaki': 3868,
#          'nic': 3866,
#          'pożyczki': 3850,
#          'dochód': 3832,
#          'trochę': 3806,
#          'twoja': 3798,
#          '20': 3788,
#          'oczywiście': 3772,
#          'wydaje': 3763,
#          'karty': 3747,
#          'prawie': 3746,
#          'każdy': 3726,
#          'ryzyko': 3718,
#          '$': 3703,
#          'zwykle': 3685,
#          'uwagę': 3683,
#          'jej': 3679,
#          'ta': 3654,
#          'rynek': 3640,
#          'część': 3630,
#          'gdzie': 3624,
#          'płatności': 3612,
#          'nieruchomości': 3590,
#          'której': 3558,
#          'tutaj': 3537,
#          'zamiast': 3494,
#          'między': 3473,
#          'powodu': 3443,
#          'kupić': 3441,
#          'mogę': 3427,
#          'by': 3417,
#          'ira': 3412,
#          'dom': 3399,
#          'chociaż': 3398,
#          'banku': 3394,
#          'twoim': 3389,
#          'inwestycji': 3384,
#          'pytanie': 3363,
#          'chodzi': 3361,
#          'poza': 3355,
#          'twojego': 3348,
#          'ktoś': 3332,
#          'zbyt': 3330,
#          'kto': 3298,
#          'wtedy': 3286,
#          'podatki': 3278,
#          'często': 3262,
#          'gdyby': 3241,
#          'ani': 3219,
#          'tam': 3198,
#          'musi': 3169,
#          'niektóre': 3163,
#          'którego': 3158,
#          'podatek': 3142,
#          'twojej': 3141,
#          'zapłacić': 3139,
#          'tę': 3108,
#          'celu': 3100,
#          'jeszcze': 3092,
#          'byłoby': 3087,
#          '50': 3055,
#          'firm': 3035,
#          'albo': 3026,
#          'należy': 3020,
#          'koszty': 3002,
#          'kredyt': 2980,
#          'była': 2979,
#          '30': 2979,
#          'fundusze': 2958,
#          'problem': 2904,
#          'samo': 2899,
#          'temat': 2895,
#          'tys': 2883,
#          'także': 2872,
#          'takich': 2867,
#          'wszyscy': 2861,
#          'opłaty': 2853,
#          'zostanie': 2848,
#          'opcji': 2840,
#          'dość': 2837,
#          'lepiej': 2836,
#          'miał': 2824,
#          'pracę': 2823,
#          'biorąc': 2820,
#          'podatków': 2812,
#          'jeden': 2806,
#          'znaleźć': 2787,
#          'wysokości': 2775,
#          'wydatki': 2745,
#          'były': 2734,
#          'ty': 2726,
#          'wynosi': 2724,
#          'rok': 2724,
#          'zwrot': 2720,
#          'strony': 2712,
#          '4': 2710,
#          'transakcji': 2710,
#          'odsetki': 2705,
#          'wiem': 2683,
#          'rzeczywistości': 2673,
#          'każdego': 2659,
#          'musiał': 2658,
#          'rząd': 2653,
#          'swoim': 2645,
#          'fundusz': 2635,
#          'swojego': 2635,
#          'pewien': 2635,
#          'muszą': 2631,
#          'swoją': 2619,
#          'ryzyka': 2614,
#          'sam': 2612,
#          'czasie': 2609,
#          'banki': 2607,
#          'moje': 2582,
#          'swój': 2577,
#          'one': 2575,
#          '15': 2574,
#          'rzecz': 2526,
#          'zyski': 2523,
#          'swojej': 2500,
#          'zysków': 2482,
#          'oraz': 2478,
#          'cenę': 2474,
#          'dywidendy': 2470,
#          'jakie': 2447,
#          'kosztów': 2443,
#          'płacić': 2441,
#          'osoby': 2434,
#          '|': 2430,
#          'ją': 2427,
#          'ponad': 2410,
#          'zostać': 2402,
#          'żadnych': 2393,
#          'oszczędności': 2393,
#          'chcą': 2389,
#          'dzięki': 2383,
#          'momencie': 2377,
#          'samochód': 2366,
#          'dwa': 2363,
#          'zazwyczaj': 2363,
#          'zależy': 2362,
#          'potrzebujesz': 2356,
#          'istnieją': 2350,
#          'dochodu': 2348,
#          'inny': 2345,
#          'mój': 2345,
#          'odpowiedź': 2343,
#          'innego': 2342,
#          'wzrost': 2321,
#          'sytuacji': 2317,
#          'kredytowej': 2317,
#          'jednym': 2298,
#          'dług': 2298,
#          'całkowicie': 2280,
#          'temu': 2267,
#          'informacji': 2267,
#          'czego': 2260,
#          'kapitału': 2257,
#          'kwotę': 2255,
#          'obecnie': 2255,
#          'mówi': 2251,
#          'wystarczająco': 2249,
#          'gotówki': 2246,
#          'rocznie': 2242,
#          'koszt': 2238,
#          'miesięcy': 2233,
#          'moim': 2221,
#          'dokładnie': 2220,
#          'odsetek': 2214,
#          'dnia': 2212,
#          'pracowników': 2210,
#          'kilku': 2207,
#          'ubezpieczenie': 2205,
#          'zysk': 2205,
#          'cały': 2201,
#          'zwrotu': 2196,
#          'chyba': 2193,
#          'aktywów': 2192,
#          'płacisz': 2190,
#          'zależności': 2187,
#          'względu': 2175,
#          'funduszu': 2174,
#          'zanim': 2162,
#          'obligacji': 2156,
#          'twoich': 2149,
#          'działa': 2147,
#          'opodatkowaniu': 2146,
#          'przynajmniej': 2145,
#          'dobre': 2145,
#          'sprzedać': 2140,
#          'każdym': 2128,
#          'usługi': 2126,
#          'hipotecznego': 2124,
#          'właśnie': 2112,
#          'powiedzieć': 2108,
#          'kraju': 2107,
#          'razie': 2104,
#          'funduszy': 2097,
#          '500': 2076,
#          '6': 2069,
#          'życie': 2068,
#          'większości': 2060,
#          'lata': 2048,
#          'różne': 2038,
#          'tyle': 2034,
#          'dobry': 2033,
#          'zasadniczo': 2030,
#          'różnych': 2029,
#          'życia': 2025,
#          'chce': 2024,
#          'kwoty': 2018,
#          'dotyczące': 2011,
#          'faktycznie': 2009,
#          'dopóki': 2003,
#          'danych': 1997,
#          'korzyści': 1993,
#          'możliwe': 1989,
#          'poziomie': 1984,
#          'sprzedaż': 1983,
#          'ja': 1975,
#          'osoba': 1973,
#          'wygląda': 1965,
#          'etf': 1957,
#          'obligacje': 1956,
#          'jedną': 1954,
#          'irs': 1948,
#          'nad': 1946,
#          'liczby': 1939,
#          'odpowiedzi': 1939,
#          'koncie': 1937,
#          'dni': 1935,
#          'duże': 1930,
#          'ogólnie': 1927,
#          'innym': 1923,
#          'np': 1922,
#          'dochodów': 1917,
#          'moja': 1916,
#          'wydatków': 1915,
#          'miejsce': 1908,
#          'firmę': 1902,
#          'oto': 1899,
#          'części': 1882,
#          'świecie': 1857,
#          'samochodu': 1854,
#          'rodzaju': 1851,
#          '25': 1848,
#          'twoją': 1837,
#          'stopy': 1834,
#          'powinien': 1829,
#          'zgodnie': 1827,
#          'ponownie': 1818,
#          'powiedzmy': 1817,
#          'stawki': 1802,
#          'żeby': 1800,
#          'stronie': 1795,
#          'informacje': 1793,
#          'nikt': 1792,
#          'system': 1786,
#          'netto': 1785,
#          'nieco': 1785,
#          'podatkowe': 1785,
#          'wcześniej': 1783,
#          'samym': 1779,
#          'taki': 1772,
#          'niektórych': 1771,
#          'poniżej': 1769,
#          'mojego': 1768,
#          'końcu': 1763,
#          'szybko': 1760,
#          'nadzieję': 1759,
#          'mógł': 1756,
#          'opcje': 1745,
#          'według': 1735,
#          'zarówno': 1733,
#          'później': 1733,
#          'najbardziej': 1729,
#          'polega': 1728,
#          'pamiętaj': 1728,
#          'powyżej': 1721,
#          'mówiąc': 1715,
#          'on': 1711,
#          '1000': 1711,
#          'e': 1709,
#          'pożyczkę': 1706,
#          'zwłaszcza': 1700,
#          'cenie': 1698,
#          'potem': 1697,
#          'porównaniu': 1694,
#          'cen': 1689,
#          'roth': 1677,
#          'online': 1677,
#          'klientów': 1676,
#          'firmie': 1673,
#          'uważam': 1665,
#          'mamy': 1662,
#          'bezpośrednio': 1654,
#          'brzmi': 1650,
#          'jednego': 1648,
#          'niektórzy': 1645,
#          'koniec': 1644,
#          'prawo': 1644,
#          'dzieci': 1641,
#          'został': 1641,
#          'zakupu': 1640,
#          'powinno': 1634,
#          'ubezpieczenia': 1632,
#          'miesięcznie': 1629,
#          'wypłaty': 1622,
#          'inni': 1617,
#          'raz': 1615,
#          'lepsze': 1614,
#          'kwota': 1612,
#          'emeryturę': 1611,
#          'inwestycje': 1610,
#          'x': 1606,
#          'robią': 1604,
#          'przyszłości': 1603,
#          'miesiąc': 1603,
#          'miejsca': 1602,
#          'nas': 1601,
#          'daje': 1598,
#          'dzieje': 1592,
#          'mojej': 1588,
#          'łatwo': 1588,
#          'wiesz': 1586,
#          'procent': 1584,
#          'zakup': 1584,
#          'pomóc': 1565,
#          'niezależnie': 1563,
#          'dane': 1561,
#          'hipoteczny': 1558,
#          'artykuł': 1553,
#          'robi': 1552,
#          'kredytową': 1552,
#          'czym': 1547,
#          'wyższe': 1542,
#          'tj': 1542,
#          'wzrostu': 1539,
#          'podstawie': 1537,
#          'razy': 1535,
#          'zostały': 1527,
#          'usług': 1525,
#          'amazon': 1523,
#          'podobnie': 1522,
#          'robić': 1518,
#          'siebie': 1516,
#          'posiadanie': 1515,
#          'razem': 1511,
#          'taka': 1507,
#          'zjednoczonych': 1503,
#          'dotyczy': 1502,
#          'handlu': 1500,
#          'zobaczyć': 1495,
#          'nowy': 1494,
#          'poprzez': 1492,
#          'aktywa': 1489,
#          '+': 1482,
#          'zysku': 1481,
#          'kapitał': 1480,
#          'google': 1479,
#          'ponadto': 1471,
#          'jakiś': 1455,
#          'drugiej': 1449,
#          'innymi': 1448,
#          'prawa': 1441,
#          '40': 1438,
#          'prawda': 1437,
#          'kogoś': 1436,
#          'saldo': 1429,
#          'pierwsze': 1429,
#          'powiedział': 1427,
#          'możliwości': 1425,
#          'opłat': 1423,
#          'wymaga': 1422,
#          'takim': 1418,
#          'dodatkowe': 1418,
#          'długu': 1414,
#          'pomysł': 1408,
#          'najmniej': 1408,
#          'takiego': 1404,
#          'najlepsze': 1397,
#          'latach': 1392,
#          'dalej': 1392,
#          'nowe': 1389,
#          'czasami': 1387,
#          'pytania': 1387,
#          'dwóch': 1386,
#          'ogóle': 1386,
#          'wpływ': 1385,
#          'mówisz': 1382,
#          'pewnością': 1380,
#          'jaką': 1377,
#          'rozumiem': 1372,
#          'zgadzam': 1369,
#          'b': 1369,
#          'pomocą': 1365,
#          'sądzę': 1364,
#          'podatkowych': 1361,
#          'plan': 1361,
#          'chcę': 1358,
#          'we': 1358,
#          'dzień': 1354,
#          'każda': 1350,
#          'spłacić': 1350,
#          'umowy': 1349,
#          'kartę': 1348,
#          'pozwolić': 1346,
#          'okresie': 1342,
#          'każdej': 1337,
#          'zainwestować': 1337,
#          'dużej': 1336,
#          'myśli': 1335,
#          'warto': 1332,
#          'praca': 1330,
#          'pozwala': 1329,
#          'biznes': 1328,
#          'czek': 1325,
#          'inwestorów': 1324,
#          '12': 1318,
#          'dochody': 1317,
#          'u': 1310,
#          'wszelkie': 1309,
#          'ważne': 1308,
#          'pożyczek': 1304,
#          'jedna': 1295,
#          'całkiem': 1294,
#          '7': 1289,
#          'sposobem': 1288,
#          'brak': 1285,
#          'zakładając': 1285,
#          'zasady': 1284,
#          'gotówkę': 1284,
#          'możliwość': 1283,
#          'banków': 1283,
#          'warte': 1283,
#          '0': 1280,
#          'zdecydowanie': 1275,
#          'jednej': 1273,
#          'mu': 1272,
#          'wieku': 1272,
#          'kont': 1267,
#          'k': 1264,
#          'środków': 1257,
#          'bo': 1256,
#          'czegoś': 1252,
#          'zasadzie': 1251,
#          'długo': 1250,
#          'osobiście': 1250,
#          'kredytowe': 1249,
#          'okres': 1249,
#          'prawdopodobne': 1249,
#          'kart': 1244,
#          'oni': 1243,
#          'niego': 1242,
#          'godzin': 1241,
#          'zostaną': 1241,
#          'rachunku': 1241,
#          'problemy': 1234,
#          'oprocentowanie': 1234,
#          '8': 1229,
#          'powodów': 1227,
#          'same': 1227,
#          'powinna': 1224,
#          'widzę': 1224,
#          'podatkowym': 1224,
#          'kredytów': 1223,
#          'otrzymasz': 1222,
#          'zadłużenia': 1222,
#          'wszystkim': 1221,
#          'straty': 1220,
#          'płacą': 1219,
#          'wziąć': 1217,
#          'wyniki': 1214,
#          'moich': 1206,
#          'kupujesz': 1203,
#          'inwestorzy': 1201,
#          'stanach': 1200,
#          'dwie': 1200,
#          'trudno': 1200,
#          'płaci': 1198,
#          'najpierw': 1197,
#          'została': 1197,
#          'cóż': 1196,
#          'kupować': 1189,
#          'wraz': 1183,
#          'nimi': 1182,
#          'możemy': 1182,
#          'oferuje': 1179,
#          'spłaty': 1179,
#          'znaczenia': 1177,
#          'powinny': 1167,
#          'najlepszy': 1165,
#          'liczba': 1165,
#          'sprawę': 1164,
#          'otrzymujesz': 1163,
#          'pracodawcy': 1163,
#          'składki': 1162,
#          'miejscu': 1161,
#          'byłaby': 1160,
#          'branży': 1158,
#          'punktu': 1158,
#          'pierwszy': 1158,
#          'inaczej': 1155,
#          'byłby': 1153,
#          'nowego': 1152,
#          'miałem': 1148,
#          'wciąż': 1147,
#          'fakt': 1145,
#          'wykorzystać': 1142,
#          'większe': 1141,
#          'rzeczą': 1135,
#          'związane': 1134,
#          'duży': 1133,
#          'żadnego': 1132,
#          'jakości': 1129,
#          'nowych': 1126,
#          'kupna': 1125,
#          'finansowych': 1124,
#          'niskie': 1123,
#          'dobrym': 1122,
#          'wysokie': 1119,
#          'inną': 1115,
#          'kredytowych': 1113,
#          '200': 1113,
#          'dobra': 1112,
#          'mieli': 1110,
#          'nim': 1108,
#          'generalnie': 1106,
#          'byli': 1105,
#          'rachunek': 1105,
#          'zarobić': 1105,
#          'pewne': 1103,
#          'dostępne': 1099,
#          'aż': 1098,
#          'ilość': 1098,
#          'autotldr': 1098,
#          'giełdzie': 1097,
#          'pracować': 1097,
#          'środki': 1096,
#          'najlepiej': 1095,
#          'zmiany': 1094,
#          'podatkowego': 1090,
#          'początku': 1087,
#          'pewno': 1086,
#          'właściwie': 1085,
#          'wiedzieć': 1084,
#          'ramach': 1083,
#          'wielkiej': 1083,
#          'numer': 1080,
#          'stopa': 1080,
#          'własne': 1078,
#          '401(k': 1076,
#          'porządku': 1075,
#          'myślisz': 1075,
#          'powodem': 1071,
#          'uniknąć': 1071,
#          'problemem': 1071,
#          'przeciwko': 1062,
#          'stosunku': 1060,
#          'typu': 1060,
#          'sens': 1060,
#          'transakcje': 1059,
#          'pośrednictwem': 1059,
#          'ilości': 1059,
#          'najlepszym': 1058,
#          'czyli': 1055,
#          'jesteśmy': 1055,
#          'historii': 1051,
#          '60': 1051,
#          'dużą': 1050,
#          '90': 1048,
#          'robisz': 1047,
#          'doświadczenia': 1046,
#          'głównie': 1045,
#          'jedynym': 1044,
#          'problemu': 1043,
#          'rację': 1042,
#          'finansowe': 1039,
#          'pieniędzmi': 1039,
#          'mało': 1039,
#          'dostęp': 1036,
#          'sprawia': 1036,
#          'użyć': 1035,
#          'załóżmy': 1035,
#          'akcję': 1033,
#          'salda': 1029,
#          'pożyczka': 1029,
#          'cokolwiek': 1027,
#          'różnica': 1027,
#          'ostatnich': 1026,
#          'produktów': 1024,
#          'umiejętności': 1023,
#          'produkty': 1023,
#          'zostało': 1022,
#          'otrzymać': 1021,
#          'kapitałowych': 1019,
#          'domów': 1019,
#          'byłem': 1019,
#          'dobrą': 1018,
#          'plus': 1014,
#          'działalności': 1014,
#          'będę': 1011,
#          'klienta': 1010,
#          'udział': 1008,
#          'słowa': 1006,
#          'winien': 1006,
#          'zobacz': 1005,
#          'celem': 1005,
#          'miejsc': 1004,
#          'mogłem': 1002,
#          '80': 1002,
#          'kiedykolwiek': 1001,
#          'apple': 1000,
#          'pozycji': 1000,
#          'systemu': 1000,
#          'inwestycja': 999,
#          'inflacji': 998,
#          'trzeba': 998,
#          'milionów': 997,
#          'właścicielem': 997,
#          '401': 995,
#          'dużych': 994,
#          'rachunki': 994,
#          'strona': 993,
#          'stany': 993,
#          'zakresie': 993,
#          'abyś': 991,
#          'opcja': 988,
#          'rządu': 985,
#          's&p': 985,
#          'inwestycyjne': 984,
#          'punkt': 983,
#          'stronę': 982,
#          'samego': 981,
#          'inwestowanie': 981,
#          'pomoże': 979,
#          'pracownicy': 979,
#          'mówię': 978,
#          'waluty': 978,
#          'wyjątkiem': 974,
#          'ostatecznie': 973,
#          'przypadkach': 972,
#          'płatność': 972,
#          'trudne': 972,
#          'złe': 971,
#          'uważasz': 971,
#          'kosztuje': 971,
#          'widzenia': 970,
#          'zaoszczędzić': 968,
#          'innej': 967,
#          'złota': 966,
#          'mimo': 965,
#          'nasze': 965,
#          'zacząć': 960,
#          'tu': 959,
#          'mogli': 958,
#          'brytanii': 954,
#          'gdybyś': 953,
#          'ludziom': 953,
#          'zwroty': 952,
#          'miesiąca': 951,
#          'samą': 951,
#          'jasne': 950,
#          'celów': 947,
#          'c': 946,
#          'długi': 946,
#          'związku': 945,
#          'powrotem': 943,
#          'problemów': 943,
#          'gospodarki': 942,
#          'sprawdzić': 938,
#          'tobą': 937,
#          'stawka': 937,
#          'procentowe': 934,
#          'sama': 932,
#          'liczbę': 932,
#          'potrzeby': 931,
#          'taką': 931,
#          'muszę': 930,
#          'większą': 926,
#          'nieruchomość': 925,
#          'częścią': 924,
#          'przeciwnym': 923,
#          'podobne': 923,
#          'zapewnia': 922,
#          'chciałbym': 922,
#          'biznesu': 921,
#          'utrzymać': 920,
#          'poziom': 919,
#          'znajduje': 919,
#          'obejmuje': 918,
#          'całym': 917,
#          'rodzaj': 917,
#          'handel': 916,
#          'znam': 916,
#          'mówią': 915,
#          'dolara': 911,
#          'message': 909,
#          'widziałem': 908,
#          'powinni': 907,
#          'spółki': 907,
#          'czynsz': 907,
#          'wynik': 905,
#          'nam': 905,
#          'własnego': 905,
#          'bankowe': 902,
#          'własny': 901,
#          'pewnym': 901,
#          'the': 901,
#          'ona': 900,
#          'dowiedzieć': 900,
#          'proces': 898,
#          'zmienić': 897,
#          'niższe': 896,
#          'badania': 896,
#          'źle': 896,
#          'trzy': 894,
#          'inwestować': 894,
#          'spłatę': 892,
#          'inwestycyjnych': 888,
#          'doświadczenie': 888,
#          'duża': 888,
#          'sytuacja': 886,
#          'produkt': 884,
#          'drugie': 884,
#          'sieci': 883,
#          'inwestowania': 883,
#          'planu': 882,
#          'długów': 881,
#          'samochodów': 881,
#          'niewiele': 877,
#          'gdybym': 876,
#          'limit': 876,
#          'compose': 875,
#          'obu': 874,
#          'dostać': 874,
#          'opłatę': 872,
#          'wymiany': 868,
#          'upewnij': 868,
#          'góry': 867,
#          'finansów': 867,
#          'sprawdź': 867,
#          'stać': 867,
#          'klasy': 865,
#          'kiedyś': 865,
#          'miała': 862,
#          'dzisiaj': 860,
#          'działalność': 858,
#          'dać': 858,
#          'euro': 856,
#          'pracodawca': 855,
#          'zrozumieć': 853,
#          'wysokiej': 852,
#          'kółko': 848,
#          'kluczowe': 846,
#          'sprzedawać': 845,
#          'zapłacisz': 844,
#          'przepisy': 843,
#          'powód': 842,
#          'portfela': 842,
#          'górę': 842,
#          'jaka': 840,
#          'całe': 838,
#          'większej': 837,
#          's': 835,
#          '401k': 834,
#          'większy': 833,
#          'model': 833,
#          'takiej': 832,
#          'wystarczy': 832,
#          '65': 832,
#          'wiki': 826,
#          'szkoły': 826,
#          'inna': 825,
#          'samej': 825,
#          'komentarze': 822,
#          'zdaniem': 822,
#          'zarabiają': 817,
#          'wskaźnik': 816,
#          'szczególnie': 816,
#          'średniej': 816,
#          'staje': 813,
#          'złoto': 813,
#          'pierwszym': 812,
#          'coraz': 811,
#          '2000': 811,
#          'jedno': 811,
#          'wydać': 811,
#          'żadnej': 809,
#          'płacenia': 809,
#          'kupowanie': 808,
#          'chwili': 808,
#          'skorzystać': 808,
#          'ryzykiem': 806,
#          'wybór': 806,
#          'opinie': 804,
#          'zawiera': 804,
#          'stanów': 804,
#          'llc': 803,
#          'rodziny': 801,
#          'wzrośnie': 801,
#          'wie': 799,
#          'zarabiać': 799,
#          'pory': 797,
#          'jednocześnie': 797,
#          'dotyczących': 796,
#          'znowu': 795,
#          'opcję': 794,
#          'wybrać': 794,
#          'popyt': 792,
#          'spada': 791,
#          'decyzji': 790,
#          'zapewnić': 790,
#          'tymi': 790,
#          'zakupy': 789,
#          'internetowej': 788,
#          'oferty': 786,
#          'rynki': 784,
#          'poziomu': 783,
#          'odliczyć': 783,
#          'natychmiast': 782,
#          'wiedzą': 782,
#          'raczej': 781,
#          'gospodarka': 781,
#          'wynagrodzenie': 781,
#          'naszych': 780,
#          ...})

# %% [markdown]
# Now for the queries

# %%
frequency[1]
# Out:
# Counter({'czy': 1963,
#          'w': 1850,
#          'na': 1462,
#          'jak': 1155,
#          'z': 1152,
#          'i': 844,
#          'jest': 837,
#          'do': 618,
#          'się': 561,
#          'akcji': 553,
#          'dla': 485,
#          'co': 478,
#          'dlaczego': 469,
#          'są': 456,
#          'nie': 416,
#          'akcje': 407,
#          'mogę': 406,
#          'za': 384,
#          'od': 350,
#          'to': 326,
#          'o': 321,
#          'lub': 307,
#          'jakie': 294,
#          'jeśli': 294,
#          'powinienem': 283,
#          'a': 232,
#          'jaki': 222,
#          'po': 219,
#          'usa': 218,
#          'może': 211,
#          'aby': 209,
#          'firmy': 200,
#          'jako': 187,
#          'pieniądze': 180,
#          'sposób': 176,
#          'sprzedaży': 153,
#          'jaka': 148,
#          'etf': 148,
#          'pieniędzy': 145,
#          'gdy': 141,
#          'mam': 140,
#          'opcji': 140,
#          'podatki': 138,
#          'domu': 138,
#          'że': 131,
#          'kredytu': 130,
#          'gdzie': 127,
#          'bez': 125,
#          'kredyt': 124,
#          'można': 124,
#          'niż': 122,
#          'które': 121,
#          'ceny': 118,
#          'ira': 117,
#          'opcje': 117,
#          'przez': 116,
#          'między': 115,
#          'mojego': 114,
#          'podatku': 112,
#          'ma': 111,
#          'przed': 111,
#          'przy': 109,
#          'ze': 109,
#          'kiedy': 109,
#          'cena': 107,
#          'karty': 106,
#          'fundusze': 106,
#          'nieruchomości': 104,
#          'dywidendy': 102,
#          'moje': 98,
#          'istnieje': 98,
#          'kupić': 98,
#          'podatek': 97,
#          'kredytowej': 95,
#          'konto': 94,
#          'rynku': 93,
#          'konta': 92,
#          'firma': 91,
#          'usd': 90,
#          'dom': 89,
#          'znaleźć': 89,
#          'być': 89,
#          'wartość': 88,
#          'zrobić': 88,
#          'podatkowe': 87,
#          'tylko': 84,
#          'ile': 84,
#          'kredytową': 84,
#          'inwestycji': 82,
#          'dotyczące': 80,
#          'mój': 80,
#          'ale': 79,
#          'tak': 77,
#          'muszę': 76,
#          'pożyczki': 75,
#          'mojej': 73,
#          'samochodu': 72,
#          'akcjami': 72,
#          'czym': 71,
#          'zainwestować': 71,
#          'inwestować': 71,
#          'dochód': 70,
#          'wartości': 70,
#          'stanie': 70,
#          'mogą': 70,
#          'llc': 69,
#          'zysków': 69,
#          'oznacza': 68,
#          'sprzedaż': 68,
#          'obliczyć': 67,
#          'który': 66,
#          'online': 66,
#          'płatności': 66,
#          'lat': 66,
#          'cenę': 65,
#          'giełdzie': 65,
#          'funduszu': 65,
#          'fundusz': 65,
#          'różnica': 63,
#          'hipoteczny': 63,
#          'inwestowania': 63,
#          'pod': 62,
#          'hipotecznego': 62,
#          '1': 61,
#          'oszczędności': 61,
#          'przypadku': 60,
#          'podczas': 59,
#          'wielkiej': 59,
#          'brytanii': 59,
#          'roku': 59,
#          'mi': 59,
#          'tym': 59,
#          'duplikować': 59,
#          'uzyskać': 59,
#          'roth': 58,
#          'samochód': 57,
#          'inwestowanie': 57,
#          'obligacji': 57,
#          'płacić': 56,
#          '000': 56,
#          'działa': 56,
#          '401k': 56,
#          'która': 55,
#          'ubezpieczenie': 54,
#          'opłaty': 54,
#          'pracy': 54,
#          'handel': 54,
#          'funduszy': 54,
#          'kredytowych': 52,
#          'ktoś': 52,
#          'vs': 52,
#          'inwestycyjne': 52,
#          'handlu': 51,
#          '401(k': 51,
#          'aktywów': 50,
#          'jestem': 50,
#          'ich': 50,
#          'mają': 50,
#          'więcej': 50,
#          'kupna': 50,
#          'sobie': 49,
#          'zyski': 49,
#          'dane': 48,
#          'zamiast': 47,
#          'spółki': 47,
#          'mnie': 47,
#          'jakieś': 47,
#          'bank': 47,
#          'obligacje': 47,
#          'podatków': 46,
#          'indiach': 46,
#          'zwrot': 46,
#          'kosztów': 45,
#          '2': 45,
#          'swoje': 45,
#          'kapitałowych': 44,
#          'zakup': 43,
#          '1099': 43,
#          'moim': 43,
#          'tego': 43,
#          'transakcji': 42,
#          'banku': 42,
#          'finance': 42,
#          'dochodu': 41,
#          'pożyczkę': 41,
#          'portfela': 41,
#          'kapitału': 40,
#          's': 40,
#          'zysk': 40,
#          'moich': 40,
#          'cen': 40,
#          'zwrotu': 40,
#          'sprzedać': 40,
#          'kapitałowe': 40,
#          'wpływ': 40,
#          'inwestycje': 39,
#          'mieć': 39,
#          'działają': 38,
#          'firmę': 38,
#          'odliczyć': 38,
#          'kartą': 37,
#          'uwagę': 37,
#          'naprawdę': 37,
#          'gotówki': 37,
#          'inne': 37,
#          'kupować': 37,
#          'spłacić': 36,
#          'kart': 36,
#          'kupowanie': 36,
#          'moją': 36,
#          'kredytowe': 36,
#          'lepiej': 36,
#          'dzieje': 36,
#          'ryzyko': 36,
#          'zakupu': 36,
#          'google': 36,
#          'bankowe': 35,
#          'osobistych': 35,
#          'nadal': 35,
#          'kto': 35,
#          'e': 35,
#          'najlepszy': 35,
#          'wydatki': 34,
#          'pomocą': 34,
#          'opodatkowaniu': 34,
#          'cenie': 34,
#          'kanadzie': 34,
#          'ubezpieczenia': 34,
#          'konsekwencje': 34,
#          'możesz': 34,
#          'danych': 34,
#          'inwestycyjnego': 34,
#          'inwestycyjnych': 34,
#          'istnieją': 34,
#          'zacząć': 34,
#          'należy': 34,
#          'moja': 33,
#          'kraju': 33,
#          'zapłacić': 33,
#          'dobry': 33,
#          'finansów': 33,
#          'banki': 32,
#          '401': 32,
#          '$': 32,
#          'porównaniu': 32,
#          'stopy': 32,
#          'oprocentowanie': 32,
#          'otrzymać': 32,
#          'wpływa': 32,
#          'k': 32,
#          'poniżej': 32,
#          'pracodawcy': 32,
#          'pytanie': 32,
#          'rynek': 32,
#          'ryzyka': 31,
#          'czego': 31,
#          'yahoo': 31,
#          'sens': 31,
#          'je': 31,
#          'informacje': 31,
#          'netto': 31,
#          'czas': 31,
#          'ipo': 31,
#          'indii': 30,
#          'irs': 30,
#          '10': 30,
#          'dobra': 30,
#          'rachunku': 30,
#          'wziąć': 30,
#          'dochodów': 30,
#          'inwestycja': 30,
#          'zlecenia': 30,
#          's&p': 30,
#          'jej': 30,
#          'korzyści': 30,
#          'wynajem': 29,
#          'dług': 29,
#          'odsetek': 29,
#          'kartę': 29,
#          'koncie': 29,
#          'go': 29,
#          'dywidend': 29,
#          'ludzie': 29,
#          'nowy': 28,
#          'wydatków': 28,
#          'straty': 28,
#          'wypłaty': 28,
#          'teraz': 28,
#          'kupno': 28,
#          'nieruchomość': 28,
#          'duplikat': 28,
#          'akcjach': 28,
#          'osoby': 27,
#          'zostanie': 27,
#          'warto': 27,
#          'powinien': 27,
#          'tys': 27,
#          'corp': 27,
#          'podatkowych': 27,
#          'giełdowych': 27,
#          'finansowe': 27,
#          'gotówkę': 27,
#          'rachunek': 27,
#          'te': 27,
#          'związane': 27,
#          'dywidendę': 27,
#          'wskaźnik': 27,
#          'zawsze': 27,
#          'p': 27,
#          'firm': 26,
#          '100': 26,
#          'odsetki': 26,
#          'wymiany': 26,
#          'osoba': 26,
#          'którym': 26,
#          'osób': 26,
#          'opłat': 26,
#          'dolarów': 26,
#          'sprawdzić': 26,
#          'pracę': 26,
#          'finanse': 26,
#          'sprzedawać': 26,
#          'strategia': 26,
#          'dnia': 26,
#          'celu': 26,
#          'czasie': 26,
#          'kredytów': 26,
#          'indeksowe': 26,
#          'nowego': 25,
#          'małej': 25,
#          'poza': 25,
#          'chce': 25,
#          'aktywa': 25,
#          'inwestor': 25,
#          'jego': 25,
#          'wykorzystać': 25,
#          'inwestorów': 25,
#          'plan': 25,
#          'limit': 25,
#          'coś': 25,
#          'limitem': 25,
#          'handlować': 25,
#          'skąd': 25,
#          'wzrost': 25,
#          'stop': 25,
#          'czeku': 24,
#          'wybrać': 24,
#          'zgłosić': 24,
#          'wszystkie': 24,
#          'vat': 24,
#          'znaczenie': 24,
#          'dobre': 24,
#          'pomysł': 24,
#          'innych': 24,
#          'koszty': 24,
#          'firmie': 24,
#          'zaoszczędzić': 24,
#          '500': 24,
#          'zadłużenia': 24,
#          'kapitał': 24,
#          'historyczne': 24,
#          'kapitalizacji': 24,
#          'będzie': 24,
#          'emeryturę': 24,
#          'vanguard': 24,
#          '0': 23,
#          '30': 23,
#          'użyć': 23,
#          'jakich': 23,
#          'ciągu': 23,
#          'dochodowego': 23,
#          'już': 23,
#          'gotówką': 23,
#          'wielu': 23,
#          'spółka': 23,
#          'pierwszy': 23,
#          'własny': 23,
#          'prostu': 23,
#          'różnych': 23,
#          'isa': 23,
#          'forex': 23,
#          'inwestorzy': 23,
#          'rynkowa': 23,
#          'dokładnie': 23,
#          'opcja': 23,
#          'giełdy': 23,
#          'czasu': 22,
#          'złoto': 22,
#          'kupowania': 22,
#          'czek': 22,
#          'usługi': 22,
#          'celów': 22,
#          'espp': 22,
#          'finansowych': 22,
#          'ten': 22,
#          'koszt': 22,
#          '20': 22,
#          'bardzo': 22,
#          'spłaty': 22,
#          'zapasów': 22,
#          'futures': 22,
#          'procent': 22,
#          'życie': 22,
#          'bankowego': 21,
#          'dni': 21,
#          'możliwe': 21,
#          'inwestycyjny': 21,
#          'korzystać': 21,
#          'walut': 21,
#          'długo': 21,
#          'środki': 21,
#          'rok': 21,
#          'wady': 21,
#          'waluty': 21,
#          'zysku': 21,
#          'plusy': 21,
#          'minusy': 21,
#          'niektóre': 21,
#          'wskaźniki': 21,
#          'termin': 20,
#          'przenieść': 20,
#          'osobistego': 20,
#          'najlepsza': 20,
#          'tytułu': 20,
#          'dochodowy': 20,
#          'legalne': 20,
#          'potrzebuję': 20,
#          'często': 20,
#          '3': 20,
#          'zdolność': 20,
#          'amerykańskie': 20,
#          'biorąc': 20,
#          'wiele': 20,
#          'procentowe': 20,
#          'mniej': 20,
#          'oprogramowanie': 20,
#          'dowiedzieć': 20,
#          '5': 20,
#          'oszustwo': 20,
#          'innego': 20,
#          'pracodawca': 20,
#          'gnucash': 20,
#          'emerytury': 20,
#          'obliczanie': 20,
#          'zlecenie': 20,
#          'giełda': 20,
#          'miesięcy': 20,
#          'kwotę': 20,
#          'zakupie': 20,
#          'portfel': 20,
#          'opcjami': 20,
#          'ask': 20,
#          'właściciel': 19,
#          'praca': 19,
#          'składki': 19,
#          'itp': 19,
#          'opodatkowanie': 19,
#          'wielka': 19,
#          'brytania': 19,
#          'podatkowym': 19,
#          'formularz': 19,
#          'której': 19,
#          'kredytowa': 19,
#          'miałaby': 19,
#          'składek': 19,
#          'podatkowego': 19,
#          'swój': 19,
#          'odliczenie': 19,
#          'pośrednictwem': 19,
#          'posiadanie': 19,
#          'paypal': 19,
#          'emerytalne': 19,
#          'zostać': 19,
#          'samochodowy': 19,
#          'warte': 19,
#          'tej': 19,
#          'papierów': 19,
#          'wartościowych': 19,
#          'muszą': 19,
#          'zasady': 19,
#          'indeksy': 19,
#          'wysokie': 19,
#          'kwoty': 19,
#          'broker': 19,
#          'chcę': 19,
#          'karta': 19,
#          'raz': 19,
#          'zrozumienie': 19,
#          'indeks': 19,
#          'finansowania': 19,
#          'amerykańskich': 19,
#          'jakiś': 19,
#          'refinansowanie': 19,
#          'funduszami': 19,
#          'zarządzania': 18,
#          'pożyczek': 18,
#          'kilka': 18,
#          'pozycji': 18,
#          'nawet': 18,
#          'wieku': 18,
#          'którzy': 18,
#          'r': 18,
#          'według': 18,
#          'informacji': 18,
#          'inwestycję': 18,
#          'dolarach': 18,
#          'wykonania': 18,
#          'salda': 18,
#          'podstawie': 18,
#          'zarobków': 18,
#          'spłatę': 18,
#          'bardziej': 18,
#          'zwroty': 18,
#          'osobiste': 17,
#          'strat': 17,
#          'saldo': 17,
#          'używać': 17,
#          'stratę': 17,
#          '15': 17,
#          'ubiegać': 17,
#          'sposoby': 17,
#          'obywatel': 17,
#          'euro': 17,
#          'takie': 17,
#          'wyjaśnić': 17,
#          'zalety': 17,
#          'oferty': 17,
#          'student': 17,
#          'złota': 17,
#          'pieniężnych': 17,
#          'duże': 17,
#          'australii': 17,
#          'płacenia': 17,
#          'obrotu': 17,
#          'hipotecznych': 17,
#          'kredyty': 17,
#          'lepsze': 17,
#          'zmienność': 17,
#          'zleceń': 17,
#          'stopa': 17,
#          'samochodowego': 17,
#          'uważane': 16,
#          'którą': 16,
#          'korzystanie': 16,
#          'ustalić': 16,
#          'kont': 16,
#          'emerytalnych': 16,
#          'pracowników': 16,
#          'odliczenia': 16,
#          'wszystkich': 16,
#          'otworzyć': 16,
#          'właściciela': 16,
#          '50': 16,
#          'których': 16,
#          'zjednoczonych': 16,
#          'zarobić': 16,
#          'wiedzieć': 16,
#          'stanach': 16,
#          'spadek': 16,
#          'np': 16,
#          'przelew': 16,
#          'będą': 16,
#          'złożyć': 16,
#          'zapasy': 16,
#          'akcjonariuszy': 16,
#          'money': 16,
#          'pożyczka': 16,
#          'powodu': 16,
#          'rzecz': 16,
#          'u': 16,
#          'bezpieczne': 16,
#          'różne': 16,
#          'dużej': 16,
#          'nasdaq': 16,
#          'rynkowej': 16,
#          'inwestowaniu': 16,
#          'oznaczają': 16,
#          'znaczy': 16,
#          'strategii': 16,
#          'zamknięcia': 16,
#          'y': 16,
#          'prania': 16,
#          'dzień': 15,
#          'podatkowy': 15,
#          'małych': 15,
#          'podstawy': 15,
#          'spółek': 15,
#          'pieniędzmi': 15,
#          'skorzystać': 15,
#          'inny': 15,
#          'dostępne': 15,
#          'właścicielem': 15,
#          'czynniki': 15,
#          'posiadania': 15,
#          'usług': 15,
#          'finansowanie': 15,
#          'najlepsze': 15,
#          'będę': 15,
#          'pracownik': 15,
#          'mieszkania': 15,
#          'dywidenda': 15,
#          'długoterminowe': 15,
#          'możemy': 15,
#          'miałby': 15,
#          'dzieci': 15,
#          'różni': 15,
#          'kup': 15,
#          'stosunku': 15,
#          'długu': 15,
#          'giełdach': 15,
#          'jaką': 15,
#          'indeksowy': 15,
#          'bid': 15,
#          'rachunków': 14,
#          '+': 14,
#          'typu': 14,
#          'transakcje': 14,
#          'robić': 14,
#          'porady': 14,
#          'krótkiej': 14,
#          'niskie': 14,
#          'wypłacić': 14,
#          'musi': 14,
#          'przelewy': 14,
#          'rynków': 14,
#          'swoich': 14,
#          'długoterminowych': 14,
#          'udział': 14,
#          'brokera': 14,
#          'wysokości': 14,
#          'wynajmu': 14,
#          'nigdy': 14,
#          'zmienić': 14,
#          'data': 14,
#          'brokerzy': 14,
#          'dokonać': 14,
#          'studenckich': 14,
#          'korzystania': 14,
#          'zmienia': 14,
#          'najbardziej': 14,
#          'podział': 14,
#          'liczba': 14,
#          'stawki': 14,
#          'opodatkowane': 14,
#          'indeksów': 14,
#          'transakcję': 14,
#          'kapitalizacja': 14,
#          'zaliczkę': 14,
#          'depozytu': 14,
#          'okresie': 14,
#          'jakiej': 14,
#          'moimi': 14,
#          'zmiany': 14,
#          'opcję': 14,
#          'ów': 14,
#          'oszczędzać': 14,
#          'powierniczy': 14,
#          'zakupy': 13,
#          'dużego': 13,
#          'ramach': 13,
#          'inwestora': 13,
#          'ue': 13,
#          'innym': 13,
#          'rodzaj': 13,
#          'składać': 13,
#          'różnice': 13,
#          'finansowej': 13,
#          'giełdowy': 13,
#          'zmiana': 13,
#          'zdrowotne': 13,
#          'pozwolić': 13,
#          'ponad': 13,
#          'cele': 13,
#          'miesiąc': 13,
#          'wyłącznie': 13,
#          'sytuacji': 13,
#          'własność': 13,
#          'lata': 13,
#          'płacę': 13,
#          'nad': 13,
#          'spółce': 13,
#          'wpływają': 13,
#          'potrzebne': 13,
#          'jednej': 13,
#          'strony': 13,
#          'innej': 13,
#          'którego': 13,
#          'spadają': 13,
#          'oszczędnościowe': 13,
#          'momencie': 13,
#          'inwestycyjną': 13,
#          'ta': 13,
#          'zasada': 13,
#          'bankowym': 13,
#          'poprzez': 13,
#          'sfinansować': 13,
#          'sam': 13,
#          'rynkowe': 13,
#          'strategie': 13,
#          'tych': 13,
#          'stosunek': 13,
#          'rachunki': 13,
#          'rosną': 13,
#          'planu': 13,
#          'cel': 13,
#          'wysokiej': 13,
#          'zagranicznych': 13,
#          'koniec': 13,
#          'kiedykolwiek': 13,
#          'takiego': 13,
#          'długi': 13,
#          'spada': 13,
#          'inflacja': 13,
#          'kurs': 13,
#          'spłata': 13,
#          'the': 13,
#          'zdolności': 13,
#          'oszczędzania': 13,
#          'wzrostu': 13,
#          'dużą': 13,
#          'kilku': 13,
#          'rentowność': 13,
#          'wolumen': 13,
#          'put': 13,
#          'call': 13,
#          'rozpoczęcie': 12,
#          'inwestycjach': 12,
#          'działalności': 12,
#          'określić': 12,
#          'zarobki': 12,
#          'we': 12,
#          'takich': 12,
#          'powoduje': 12,
#          'część': 12,
#          'niektórych': 12,
#          'prywatnej': 12,
#          'środków': 12,
#          'klienta': 12,
#          'zabezpieczyć': 12,
#          'ropy': 12,
#          'rezydentem': 12,
#          'oprogramowania': 12,
#          'dwóch': 12,
#          'zastosowanie': 12,
#          'około': 12,
#          'towary': 12,
#          'otwarcia': 12,
#          'rodziny': 12,
#          'kupuje': 12,
#          'studenta': 12,
#          'pracowniczych': 12,
#          'mówi': 12,
#          'otrzymam': 12,
#          'ją': 12,
#          'zazwyczaj': 12,
#          'dochody': 12,
#          'własności': 12,
#          'uniknąć': 12,
#          'rrsp': 12,
#          'brak': 12,
#          'dodatkowe': 12,
#          'implikacje': 12,
#          'granicą': 12,
#          'pożyczyć': 12,
#          'numer': 12,
#          'spłacać': 12,
#          'zakupem': 12,
#          'gotówka': 12,
#          'akcję': 12,
#          'dobrze': 12,
#          'nowe': 12,
#          'finansami': 12,
#          'udziały': 12,
#          'of': 12,
#          'dużo': 12,
#          'możliwość': 12,
#          'pomóc': 12,
#          'inflacji': 12,
#          'mądrze': 12,
#          'ilość': 12,
#          'powyżej': 12,
#          'oszczędzanie': 12,
#          'wyniki': 12,
#          'rynkach': 12,
#          'domów': 12,
#          'dwa': 12,
#          'masz': 12,
#          'wiadomości': 12,
#          'zły': 12,
#          'b': 12,
#          'indeksu': 12,
#          'funduszem': 12,
#          'analizy': 12,
#          'rsu': 12,
#          'wydatek': 11,
#          'strata': 11,
#          'czeków': 11,
#          'kalifornii': 11,
#          'wyceny': 11,
#          'wykonawca': 11,
#          'korporacji': 11,
#          'banków': 11,
#          'wykupić': 11,
#          'finansowo': 11,
#          'płacenie': 11,
#          'podlega': 11,
#          'nazwisko': 11,
#          '18': 11,
#          'uk': 11,
#          'każdego': 11,
#          'spoza': 11,
#          'by': 11,
#          'zarówno': 11,
#          'określonej': 11,
#          'towarów': 11,
#          'wynająć': 11,
#          'mieszkanie': 11,
#          'umowy': 11,
#          'podlegają': 11,
#          'radzić': 11,
#          'mieszkaniowy': 11,
#          'powinniśmy': 11,
#          'giełdowe': 11,
#          'zrównoważyć': 11,
#          'maklerskie': 11,
#          'źródło': 11,
#          'wycena': 11,
#          'firmą': 11,
#          'kroki': 11,
#          'wygaśnięcia': 11,
#          'ceną': 11,
#          'pieniężne': 11,
#          'udziałów': 11,
#          'sprzedawca': 11,
#          'bezpośrednio': 11,
#          'visa': 11,
#          'kogoś': 11,
#          'małe': 11,
#          'skoro': 11,
#          'zarabiają': 11,
#          'samochodów': 11,
#          'śledzenie': 11,
#          'limitu': 11,
#          'jakim': 11,
#          'swoją': 11,
#          'zabezpieczającego': 11,
#          'spłacanie': 11,
#          'brokerów': 11,
#          'porównanie': 11,
#          'inwestycją': 11,
#          'opcją': 11,
#          'oferta': 11,
#          'powinny': 11,
#          'zbyt': 11,
#          'obrocie': 11,
#          'indeksowych': 11,
#          'stopę': 11,
#          'adr': 11,
#          'dniu': 11,
#          'krótka': 11,
#          'połączenia': 11,
#          'rozliczania': 10,
#          'leasing': 10,
#          'wykorzystania': 10,
#          'odmówić': 10,
#          'oblicz': 10,
#          'uzyskanie': 10,
#          'działalność': 10,
#          'obywatela': 10,
#          'zeznaniu': 10,
#          'wniosek': 10,
#          'otrzymałem': 10,
#          'wyższe': 10,
#          'zarabia': 10,
#          'przechowywać': 10,
#          'niemczech': 10,
#          'rzeczywiście': 10,
#          'samozatrudnienia': 10,
#          'krótkoterminowe': 10,
#          'ach': 10,
#          'formularza': 10,
#          'jakiego': 10,
#          'odniesieniu': 10,
#          'formuła': 10,
#          'rzeczy': 10,
#          'wcześniej': 10,
#          'został': 10,
#          'niskich': 10,
#          'ja': 10,
#          'inwestycyjnym': 10,
#          'płatność': 10,
#          'rynki': 10,
#          'sprzedawcy': 10,
#          'sprzedażą': 10,
#          'oceny': 10,
#          'dziecka': 10,
#          'temat': 10,
#          'powód': 10,
#          'inną': 10,
#          'oszustwa': 10,
#          'były': 10,
#          'x': 10,
#          'dużych': 10,
#          'następnie': 10,
#          'swoim': 10,
#          'kredytem': 10,
#          'rodzaje': 10,
#          'zwiększyć': 10,
#          'wykorzystanie': 10,
#          'własnego': 10,
#          'ryzyku': 10,
#          'historii': 10,
#          'reit': 10,
#          'czynsz': 10,
#          'pracodawcę': 10,
#          'dow': 10,
#          'ubezpieczeniem': 10,
#          'historycznych': 10,
#          'zaliczki': 10,
#          'znacznie': 10,
#          'fha': 10,
#          'warunki': 10,
#          'góry': 10,
#          'studenckie': 10,
#          'wysokim': 10,
#          'posiadam': 10,
#          'wysoko': 10,
#          'wpłynie': 10,
#          'ex': 10,
#          'dobrą': 10,
#          'pytania': 10,
#          'emerytura': 10,
#          'prawdopodobieństwo': 10,
#          'pmi': 10,
#          'złym': 10,
#          'giełdę': 10,
#          'podstawowe': 10,
#          'całe': 10,
#          'doradcy': 10,
#          'cfd': 10,
#          'finansowy': 10,
#          'dotyczących': 10,
#          'nyse': 10,
#          'zamówienia': 10,
#          'biznesowe': 9,
#          'osobisty': 9,
#          'zarejestrować': 9,
#          '1040': 9,
#          'obliczaniu': 9,
#          'używany': 9,
#          'niskim': 9,
#          'podatkowa': 9,
#          'zarabiać': 9,
#          'amerykańskiego': 9,
#          'pomiędzy': 9,
#          'numeru': 9,
#          'nim': 9,
#          'pracownika': 9,
#          'zarządzanie': 9,
#          'międzynarodowych': 9,
#          'misc': 9,
#          'ważne': 9,
#          'zagranicy': 9,
#          'obliczania': 9,
#          'nowym': 9,
#          'hipoteczne': 9,
#          'stanu': 9,
#          'c': 9,
#          'różnią': 9,
#          'źródła': 9,
#          'dostęp': 9,
#          'nowej': 9,
#          'studia': 9,
#          'obliczenia': 9,
#          'prawie': 9,
#          'standardowe': 9,
#          'internetowe': 9,
#          'wspólne': 9,
#          'wizie': 9,
#          'wartościowe': 9,
#          'ocenić': 9,
#          'pierwszej': 9,
#          'freelancer': 9,
#          'hsa': 9,
#          'duży': 9,
#          'możliwości': 9,
#          'uśrednianie': 9,
#          'długoterminowy': 9,
#          'stronie': 9,
#          'faktycznie': 9,
#          'porównać': 9,
#          'datą': 9,
#          'kontraktu': 9,
#          'kwota': 9,
#          '6': 9,
#          'wynagrodzeń': 9,
#          'wpłacić': 9,
#          'korporacyjnych': 9,
#          'chronić': 9,
#          'książki': 9,
#          ...})

# %%
merged_frequency = frequency[0] + frequency[1]
merged_frequency
# Out:
# Counter({'w': 177216,
#          'nie': 131898,
#          'i': 127683,
#          'na': 120509,
#          'to': 116794,
#          'z': 98105,
#          'jest': 94083,
#          'że': 90152,
#          'się': 86404,
#          'do': 67219,
#          'jeśli': 52297,
#          'a': 41496,
#          'ale': 41387,
#          'o': 38524,
#          'są': 35891,
#          'jak': 34827,
#          'lub': 33523,
#          'za': 32701,
#          'aby': 31262,
#          'co': 30180,
#          'od': 30179,
#          'może': 26581,
#          'dla': 25947,
#          'po': 25934,
#          'tak': 25711,
#          'które': 24104,
#          'możesz': 23314,
#          'czy': 22248,
#          'tego': 21981,
#          'tym': 21667,
#          'ma': 20395,
#          'być': 19356,
#          'ponieważ': 18963,
#          'przez': 17949,
#          'usd': 17614,
#          'tylko': 17346,
#          'więc': 17179,
#          'niż': 16949,
#          'ich': 14620,
#          'pieniądze': 14149,
#          'więcej': 13888,
#          'gdy': 13675,
#          'jako': 13167,
#          'pieniędzy': 12423,
#          'który': 12205,
#          'mogą': 11749,
#          'masz': 11722,
#          'będzie': 11718,
#          'akcji': 10970,
#          'firmy': 10925,
#          'również': 10538,
#          'bardzo': 10202,
#          'ci': 9988,
#          'prostu': 9805,
#          'nawet': 9745,
#          'lat': 9575,
#          'mają': 9348,
#          '>': 9332,
#          'wiele': 9243,
#          'ten': 9012,
#          'te': 8807,
#          'ze': 8725,
#          'kiedy': 8704,
#          'akcje': 8524,
#          'bez': 8406,
#          'teraz': 8129,
#          'roku': 8102,
#          'prawdopodobnie': 8045,
#          'jesteś': 7936,
#          'przypadku': 7837,
#          'bardziej': 7798,
#          'ludzie': 7786,
#          'naprawdę': 7781,
#          'która': 7732,
#          'sposób': 7632,
#          'dolarów': 7585,
#          'można': 7574,
#          'twoje': 7545,
#          '000': 7479,
#          'pracy': 7346,
#          '1': 7305,
#          'go': 7250,
#          'sobie': 7207,
#          'tych': 7185,
#          'musisz': 7102,
#          '10': 7074,
#          'będziesz': 6916,
#          'je': 6886,
#          'chcesz': 6833,
#          'mieć': 6813,
#          'tej': 6804,
#          'jestem': 6716,
#          'jednak': 6709,
#          'pod': 6674,
#          'już': 6541,
#          'nadal': 6522,
#          'twój': 6512,
#          'rzeczy': 6447,
#          'firma': 6375,
#          'którzy': 6371,
#          'których': 6326,
#          'wszystkie': 6272,
#          'kilka': 6241,
#          'będą': 6149,
#          'wartość': 6082,
#          'mniej': 5998,
#          'swoje': 5930,
#          'rynku': 5858,
#          'przed': 5816,
#          'wszystko': 5799,
#          'stanie': 5774,
#          'ludzi': 5771,
#          'wartości': 5714,
#          'oznacza': 5622,
#          'mi': 5556,
#          'usa': 5537,
#          'r': 5536,
#          '2': 5520,
#          'większość': 5514,
#          'innych': 5472,
#          'mam': 5460,
#          'coś': 5453,
#          'inne': 5344,
#          'zrobić': 5332,
#          '100': 5293,
#          'było': 5265,
#          'przykład': 5169,
#          'następnie': 5167,
#          'ceny': 5165,
#          'konto': 5079,
#          'domu': 5078,
#          'przy': 5059,
#          'ile': 5039,
#          'dlaczego': 5007,
#          'itp': 5006,
#          'takie': 5002,
#          'jego': 4981,
#          'czasu': 4939,
#          'którym': 4925,
#          'wielu': 4912,
#          'znacznie': 4861,
#          'myślę': 4745,
#          'nigdy': 4660,
#          'podatku': 4637,
#          'istnieje': 4626,
#          'był': 4572,
#          'sprzedaży': 4561,
#          'czas': 4547,
#          'nich': 4535,
#          'swoich': 4496,
#          'konta': 4486,
#          'cię': 4486,
#          '5': 4465,
#          'mnie': 4445,
#          'dużo': 4442,
#          'uzyskać': 4421,
#          'około': 4411,
#          'dobrze': 4409,
#          '3': 4401,
#          'ciebie': 4400,
#          'zawsze': 4354,
#          'cena': 4247,
#          'podczas': 4210,
#          'wszystkich': 4195,
#          'kredytu': 4186,
#          '=': 4180,
#          'dlatego': 4137,
#          'którą': 4127,
#          'powinieneś': 4095,
#          'jaki': 4090,
#          'im': 4087,
#          'osób': 4079,
#          'bank': 4059,
#          'też': 3997,
#          'pożyczki': 3925,
#          'ciągu': 3914,
#          'dochód': 3902,
#          'nic': 3867,
#          'karty': 3853,
#          'mogę': 3833,
#          '20': 3810,
#          'trochę': 3809,
#          'twoja': 3801,
#          'oczywiście': 3773,
#          'wydaje': 3768,
#          'prawie': 3755,
#          'ryzyko': 3754,
#          'gdzie': 3751,
#          '$': 3735,
#          'każdy': 3729,
#          'uwagę': 3720,
#          'jej': 3709,
#          'nieruchomości': 3694,
#          'zwykle': 3691,
#          'płatności': 3678,
#          'rynek': 3672,
#          'ta': 3667,
#          'część': 3642,
#          'między': 3588,
#          'której': 3577,
#          'zamiast': 3541,
#          'tutaj': 3540,
#          'kupić': 3539,
#          'ira': 3529,
#          'dom': 3488,
#          'inwestycji': 3466,
#          'powodu': 3459,
#          'banku': 3436,
#          'by': 3428,
#          'podatki': 3416,
#          'chociaż': 3398,
#          'pytanie': 3395,
#          'twoim': 3392,
#          'ktoś': 3384,
#          'poza': 3380,
#          'chodzi': 3364,
#          'twojego': 3351,
#          'zbyt': 3341,
#          'kto': 3333,
#          'wtedy': 3289,
#          'często': 3282,
#          'gdyby': 3246,
#          'podatek': 3239,
#          'ani': 3223,
#          'tam': 3201,
#          'niektóre': 3184,
#          'musi': 3183,
#          'zapłacić': 3172,
#          'którego': 3171,
#          'twojej': 3146,
#          'celu': 3126,
#          'tę': 3115,
#          'kredyt': 3104,
#          'jeszcze': 3099,
#          'byłoby': 3091,
#          '50': 3071,
#          'fundusze': 3064,
#          'firm': 3061,
#          'należy': 3054,
#          'koszty': 3026,
#          'albo': 3026,
#          '30': 3002,
#          'była': 2983,
#          'opcji': 2980,
#          'problem': 2911,
#          'tys': 2910,
#          'samo': 2908,
#          'opłaty': 2907,
#          'temat': 2905,
#          'takich': 2879,
#          'znaleźć': 2876,
#          'zostanie': 2875,
#          'także': 2874,
#          'lepiej': 2872,
#          'wszyscy': 2865,
#          'podatków': 2858,
#          'pracę': 2849,
#          'biorąc': 2840,
#          'dość': 2838,
#          'miał': 2829,
#          'jeden': 2813,
#          'wysokości': 2789,
#          'wydatki': 2779,
#          'zwrot': 2766,
#          'transakcji': 2752,
#          'rok': 2745,
#          'były': 2744,
#          'jakie': 2741,
#          'wynosi': 2731,
#          'odsetki': 2731,
#          'ty': 2726,
#          'strony': 2725,
#          '4': 2719,
#          'fundusz': 2700,
#          'wiem': 2684,
#          'moje': 2680,
#          'rzeczywistości': 2677,
#          'każdego': 2670,
#          'musiał': 2665,
#          'rząd': 2660,
#          'swoim': 2655,
#          'muszą': 2650,
#          'ryzyka': 2645,
#          'swojego': 2643,
#          'banki': 2639,
#          'pewien': 2639,
#          'czasie': 2635,
#          'swoją': 2630,
#          'sam': 2625,
#          'swój': 2596,
#          '15': 2591,
#          'one': 2581,
#          'zyski': 2572,
#          'dywidendy': 2572,
#          'zysków': 2551,
#          'rzecz': 2542,
#          'cenę': 2539,
#          'swojej': 2508,
#          'płacić': 2497,
#          'kosztów': 2488,
#          'oraz': 2483,
#          'osoby': 2461,
#          'oszczędności': 2454,
#          'ją': 2439,
#          '|': 2430,
#          'mój': 2425,
#          'ponad': 2423,
#          'samochód': 2423,
#          'zostać': 2421,
#          'kredytowej': 2412,
#          'żadnych': 2401,
#          'chcą': 2393,
#          'dzięki': 2391,
#          'momencie': 2390,
#          'dochodu': 2389,
#          'istnieją': 2384,
#          'dwa': 2375,
#          'zazwyczaj': 2375,
#          'potrzebujesz': 2364,
#          'zależy': 2364,
#          'innego': 2362,
#          'inny': 2360,
#          'wzrost': 2346,
#          'odpowiedź': 2346,
#          'sytuacji': 2330,
#          'dług': 2327,
#          'jednym': 2304,
#          'kapitału': 2297,
#          'czego': 2291,
#          'informacji': 2285,
#          'całkowicie': 2285,
#          'gotówki': 2283,
#          'kwotę': 2275,
#          'temu': 2273,
#          'moim': 2264,
#          'mówi': 2263,
#          'obecnie': 2262,
#          'koszt': 2260,
#          'ubezpieczenie': 2259,
#          'wystarczająco': 2255,
#          'miesięcy': 2253,
#          'rocznie': 2250,
#          'zysk': 2245,
#          'dokładnie': 2243,
#          'odsetek': 2243,
#          'aktywów': 2242,
#          'funduszu': 2239,
#          'dnia': 2238,
#          'zwrotu': 2236,
#          'pracowników': 2226,
#          'kilku': 2220,
#          'obligacji': 2213,
#          'cały': 2209,
#          'działa': 2203,
#          'płacisz': 2194,
#          'chyba': 2194,
#          'zależności': 2191,
#          'hipotecznego': 2186,
#          'względu': 2181,
#          'sprzedać': 2180,
#          'opodatkowaniu': 2180,
#          'zanim': 2170,
#          'dobre': 2169,
#          'funduszy': 2151,
#          'twoich': 2150,
#          'usługi': 2148,
#          'przynajmniej': 2147,
#          'kraju': 2140,
#          'każdym': 2133,
#          'właśnie': 2120,
#          'powiedzieć': 2111,
#          'etf': 2105,
#          'razie': 2104,
#          '500': 2100,
#          'dotyczące': 2091,
#          'życie': 2090,
#          '6': 2078,
#          'dobry': 2066,
#          'większości': 2063,
#          'lata': 2061,
#          'różne': 2054,
#          'różnych': 2052,
#          'sprzedaż': 2051,
#          'chce': 2049,
#          'tyle': 2040,
#          'kwoty': 2037,
#          'zasadniczo': 2033,
#          'życia': 2031,
#          'danych': 2031,
#          'korzyści': 2023,
#          'faktycznie': 2018,
#          'możliwe': 2010,
#          'dopóki': 2005,
#          'obligacje': 2003,
#          'osoba': 1999,
#          'ja': 1985,
#          'poziomie': 1985,
#          'irs': 1978,
#          'wygląda': 1974,
#          'koncie': 1966,
#          'jedną': 1962,
#          'nad': 1959,
#          'dni': 1956,
#          'moja': 1949,
#          'dochodów': 1947,
#          'liczby': 1947,
#          'duże': 1947,
#          'wydatków': 1943,
#          'odpowiedzi': 1940,
#          'firmę': 1940,
#          'np': 1938,
#          'innym': 1936,
#          'ogólnie': 1933,
#          'samochodu': 1926,
#          'miejsce': 1913,
#          'oto': 1899,
#          'części': 1890,
#          'mojego': 1882,
#          'podatkowe': 1872,
#          'stopy': 1866,
#          'opcje': 1862,
#          'świecie': 1862,
#          'powinien': 1856,
#          'rodzaju': 1854,
#          '25': 1853,
#          'twoją': 1841,
#          'zgodnie': 1835,
#          'ponownie': 1827,
#          'informacje': 1824,
#          'powiedzmy': 1819,
#          'netto': 1816,
#          'stawki': 1816,
#          'stronie': 1804,
#          'żeby': 1804,
#          'poniżej': 1801,
#          'wcześniej': 1793,
#          'nikt': 1792,
#          'system': 1792,
#          'nieco': 1789,
#          'samym': 1788,
#          'niektórych': 1783,
#          'taki': 1776,
#          'szybko': 1767,
#          'końcu': 1764,
#          'mógł': 1763,
#          'nadzieję': 1759,
#          'według': 1753,
#          'pożyczkę': 1747,
#          'e': 1744,
#          'zarówno': 1744,
#          'online': 1743,
#          'najbardziej': 1743,
#          'później': 1741,
#          'roth': 1735,
#          'powyżej': 1733,
#          'cenie': 1732,
#          'polega': 1730,
#          'cen': 1729,
#          'pamiętaj': 1728,
#          'porównaniu': 1726,
#          '1000': 1718,
#          'mówiąc': 1716,
#          'on': 1715,
#          'zwłaszcza': 1702,
#          'potem': 1699,
#          'firmie': 1697,
#          'klientów': 1682,
#          'zakupu': 1676,
#          'uważam': 1666,
#          'ubezpieczenia': 1666,
#          'bezpośrednio': 1665,
#          'mamy': 1664,
#          'mojej': 1661,
#          'koniec': 1657,
#          'dzieci': 1656,
#          'jednego': 1655,
#          'brzmi': 1651,
#          'został': 1651,
#          'prawo': 1651,
#          'wypłaty': 1650,
#          'inwestycje': 1649,
#          'niektórzy': 1649,
#          'miesięcznie': 1638,
#          'powinno': 1636,
#          'kredytową': 1636,
#          'emeryturę': 1635,
#          'raz': 1634,
#          'lepsze': 1631,
#          'dzieje': 1628,
#          'zakup': 1627,
#          'hipoteczny': 1621,
#          'kwota': 1621,
#          'inni': 1619,
#          'czym': 1618,
#          'miesiąc': 1616,
#          'x': 1616,
#          'dane': 1609,
#          'nas': 1608,
#          'robią': 1608,
#          'miejsca': 1607,
#          'procent': 1606,
#          'przyszłości': 1604,
#          'daje': 1602,
#          'łatwo': 1591,
#          'wiesz': 1588,
#          'pomóc': 1577,
#          'niezależnie': 1563,
#          'robi': 1561,
#          'podstawie': 1555,
#          'artykuł': 1553,
#          'wzrostu': 1552,
#          'wyższe': 1552,
#          'handlu': 1551,
#          'tj': 1549,
#          'usług': 1540,
#          'razy': 1536,
#          'posiadanie': 1534,
#          'zostały': 1533,
#          'robić': 1532,
#          'amazon': 1526,
#          'podobnie': 1523,
#          'siebie': 1522,
#          'nowy': 1522,
#          'zjednoczonych': 1519,
#          'razem': 1519,
#          'taka': 1515,
#          'google': 1515,
#          'aktywa': 1514,
#          'dotyczy': 1509,
#          'poprzez': 1505,
#          'kapitał': 1504,
#          'zysku': 1502,
#          'zobaczyć': 1499,
#          '+': 1496,
#          'jakiś': 1474,
#          'ponadto': 1471,
#          'drugiej': 1453,
#          'innymi': 1452,
#          'opłat': 1449,
#          'kogoś': 1447,
#          'saldo': 1446,
#          '40': 1446,
#          'prawda': 1445,
#          'prawa': 1445,
#          'pierwsze': 1434,
#          'możliwości': 1434,
#          'pomysł': 1432,
#          'dodatkowe': 1430,
#          'wymaga': 1429,
#          'długu': 1429,
#          'powiedział': 1428,
#          'wpływ': 1425,
#          'takim': 1419,
#          'takiego': 1417,
#          'najlepsze': 1412,
#          'najmniej': 1409,
#          'zainwestować': 1408,
#          'nowe': 1401,
#          'pomocą': 1399,
#          'dwóch': 1398,
#          'pytania': 1397,
#          'dalej': 1396,
#          'czasami': 1395,
#          'latach': 1394,
#          'ogóle': 1394,
#          'jaką': 1392,
#          'podatkowych': 1388,
#          'spłacić': 1386,
#          'plan': 1386,
#          'mówisz': 1382,
#          'b': 1381,
#          'pewnością': 1380,
#          'kartę': 1377,
#          'rozumiem': 1377,
#          'chcę': 1377,
#          'we': 1370,
#          'zgadzam': 1369,
#          'dzień': 1369,
#          'sądzę': 1364,
#          'umowy': 1360,
#          'warto': 1359,
#          'pozwolić': 1359,
#          'okresie': 1356,
#          'każda': 1352,
#          'dużej': 1352,
#          'praca': 1349,
#          'inwestorów': 1349,
#          'czek': 1347,
#          'myśli': 1340,
#          'każdej': 1339,
#          'biznes': 1334,
#          'pozwala': 1334,
#          'dochody': 1329,
#          '12': 1326,
#          'u': 1326,
#          'pożyczek': 1322,
#          'ważne': 1317,
#          'gotówkę': 1311,
#          'wszelkie': 1309,
#          'zasady': 1303,
#          '0': 1303,
#          'warte': 1302,
#          'jedna': 1301,
#          'brak': 1297,
#          'k': 1296,
#          'możliwość': 1295,
#          'całkiem': 1294,
#          'banków': 1294,
#          '7': 1293,
#          'sposobem': 1292,
#          'wieku': 1290,
#          'zakładając': 1286,
#          'jednej': 1286,
#          'kredytowe': 1285,
#          'kont': 1283,
#          'kart': 1280,
#          'mu': 1276,
#          'zdecydowanie': 1275,
#          'rachunku': 1271,
#          'długo': 1271,
#          'środków': 1269,
#          'oprocentowanie': 1266,
#          'bo': 1257,
#          'okres': 1256,
#          'czegoś': 1254,
#          'zasadzie': 1252,
#          'prawdopodobne': 1250,
#          'osobiście': 1250,
#          'godzin': 1249,
#          'kredytów': 1249,
#          'niego': 1249,
#          'straty': 1248,
#          'wziąć': 1247,
#          'moich': 1246,
#          'zadłużenia': 1246,
#          'zostaną': 1245,
#          'oni': 1244,
#          'podatkowym': 1243,
#          'problemy': 1238,
#          'same': 1234,
#          '8': 1234,
#          'powinna': 1232,
#          'powodów': 1228,
#          'widzę': 1227,
#          'kupować': 1226,
#          'wyniki': 1226,
#          'płacą': 1225,
#          'inwestorzy': 1224,
#          'otrzymasz': 1223,
#          'wszystkim': 1222,
#          'stanach': 1216,
#          'kupujesz': 1212,
#          'dwie': 1206,
#          'płaci': 1205,
#          'najpierw': 1203,
#          'została': 1203,
#          'trudno': 1202,
#          'spłaty': 1201,
#          'najlepszy': 1200,
#          'możemy': 1197,
#          'cóż': 1196,
#          'pracodawcy': 1195,
#          'wraz': 1190,
#          'nimi': 1185,
#          'oferuje': 1184,
#          'składki': 1181,
#          'pierwszy': 1181,
#          'znaczenia': 1179,
#          'liczba': 1179,
#          'powinny': 1178,
#          'nowego': 1177,
#          'kupna': 1175,
#          'otrzymujesz': 1168,
#          'wykorzystać': 1167,
#          'miejscu': 1166,
#          'kredytowych': 1165,
#          'sprawę': 1165,
#          'branży': 1164,
#          'byłaby': 1162,
#          'giełdzie': 1162,
#          'związane': 1161,
#          'inaczej': 1160,
#          'punktu': 1158,
#          'byłby': 1154,
#          'wciąż': 1150,
#          'miałem': 1149,
#          'finansowych': 1146,
#          'większe': 1146,
#          'fakt': 1145,
#          'dobra': 1142,
#          'wielkiej': 1142,
#          'duży': 1142,
#          'wysokie': 1138,
#          'niskie': 1137,
#          'rzeczą': 1136,
#          'nowych': 1134,
#          'jakości': 1133,
#          'rachunek': 1132,
#          'żadnego': 1132,
#          'dobrym': 1129,
#          '401(k': 1127,
#          'inną': 1125,
#          'zarobić': 1121,
#          '200': 1117,
#          'środki': 1117,
#          'nim': 1117,
#          'dostępne': 1114,
#          'ilość': 1110,
#          'mieli': 1110,
#          'podatkowego': 1109,
#          'generalnie': 1108,
#          'zmiany': 1108,
#          'pewne': 1105,
#          'byli': 1105,
#          'najlepiej': 1103,
#          'pracować': 1101,
#          'wiedzieć': 1100,
#          'aż': 1099,
#          'autotldr': 1098,
#          'stopa': 1097,
#          'ramach': 1096,
#          'początku': 1093,
#          'właściwie': 1093,
#          'numer': 1092,
#          'sens': 1091,
#          'różnica': 1090,
#          'pewno': 1086,
#          'uniknąć': 1083,
#          'własne': 1081,
#          'pośrednictwem': 1078,
#          'porządku': 1076,
#          'myślisz': 1076,
#          'stosunku': 1075,
#          'typu': 1074,
#          'transakcje': 1073,
#          'powodem': 1071,
#          'problemem': 1071,
#          'przeciwko': 1069,
#          'ilości': 1067,
#          'finansowe': 1066,
#          'kapitałowych': 1063,
#          'dużą': 1063,
#          'historii': 1061,
#          '60': 1060,
#          'najlepszym': 1059,
#          'czyli': 1059,
#          'użyć': 1058,
#          'jesteśmy': 1056,
#          'pieniędzmi': 1054,
#          'otrzymać': 1053,
#          '90': 1051,
#          'jedynym': 1050,
#          'doświadczenia': 1050,
#          'głównie': 1047,
#          'salda': 1047,
#          'robisz': 1047,
#          'akcję': 1045,
#          'dostęp': 1045,
#          'pożyczka': 1045,
#          'problemu': 1044,
#          'rację': 1043,
#          'sprawia': 1043,
#          'mało': 1041,
#          'inwestowanie': 1038,
#          'inwestycyjne': 1036,
#          'załóżmy': 1036,
#          'domów': 1031,
#          'zostało': 1030,
#          'ostatnich': 1029,
#          'inwestycja': 1029,
#          'cokolwiek': 1029,
#          'dobrą': 1028,
#          '401': 1027,
#          'umiejętności': 1026,
#          'działalności': 1026,
#          'produktów': 1026,
#          'będę': 1026,
#          'produkty': 1025,
#          'udział': 1022,
#          'klienta': 1022,
#          'byłem': 1022,
#          'plus': 1020,
#          'pozycji': 1018,
#          's&p': 1015,
#          'kiedykolwiek': 1014,
#          'brytanii': 1013,
#          'właścicielem': 1012,
#          'winien': 1012,
#          'opcja': 1011,
#          'inflacji': 1010,
#          'apple': 1009,
#          'słowa': 1009,
#          'rachunki': 1007,
#          'miejsc': 1006,
#          'muszę': 1006,
#          'zobacz': 1006,
#          'celem': 1006,
#          'systemu': 1006,
#          '80': 1006,
#          'dużych': 1004,
#          'trzeba': 1003,
#          'strona': 1002,
#          'mogłem': 1002,
#          'zakresie': 1000,
#          'waluty': 999,
#          'milionów': 998,
#          'stany': 997,
#          'zacząć': 994,
#          'zaoszczędzić': 992,
#          'abyś': 991,
#          'jaka': 988,
#          'samego': 986,
#          'rządu': 986,
#          'stronę': 986,
#          'pomoże': 984,
#          'punkt': 984,
#          'pracownicy': 983,
#          'złota': 983,
#          'płatność': 982,
#          'innej': 980,
#          'mówię': 978,
#          'złe': 976,
#          'przypadkach': 975,
#          'kosztuje': 975,
#          'ostatecznie': 974,
#          'wyjątkiem': 974,
#          'uważasz': 972,
#          'mimo': 972,
#          'trudne': 972,
#          'handel': 970,
#          'widzenia': 970,
#          'zwroty': 970,
#          'nasze': 970,
#          'celów': 969,
#          'inwestować': 965,
#          'sprawdzić': 964,
#          'tu': 960,
#          'długi': 959,
#          'mogli': 958,
#          'c': 955,
#          'miesiąca': 955,
#          'samą': 955,
#          'gdybyś': 954,
#          'spółki': 954,
#          'procentowe': 954,
#          'ludziom': 954,
#          'nieruchomość': 953,
#          'jasne': 950,
#          'związku': 949,
#          'gospodarki': 946,
#          'inwestowania': 946,
#          'powrotem': 945,
#          'problemów': 944,
#          'stawka': 943,
#          'liczbę': 939,
#          'tobą': 937,
#          'bankowe': 937,
#          'sama': 935,
#          'taką': 935,
#          'potrzeby': 933,
#          'rodzaj': 930,
#          'częścią': 929,
#          'większą': 928,
#          'podobne': 925,
#          'zapewnia': 925,
#          'biznesu': 925,
#          'przeciwnym': 924,
#          'obejmuje': 924,
#          'własny': 924,
#          'znajduje': 923,
#          'utrzymać': 923,
#          'chciałbym': 923,
#          'inwestycyjnych': 922,
#          'mówią': 921,
#          'poziom': 921,
#          'całym': 920,
#          'dowiedzieć': 920,
#          'dolara': 918,
#          'znam': 917,
#          'czynsz': 917,
#          'własnego': 915,
#          'the': 914,
#          'zmienić': 911,
#          'spłatę': 910,
#          'powinni': 909,
#          'message': 909,
#          'widziałem': 909,
#          'wynik': 908,
#          'nam': 908,
#          'proces': 906,
#          'ona': 905,
#          'badania': 901,
#          'źle': 901,
#          'pewnym': 901,
#          'limit': 901,
#          'finansów': 900,
#          'niższe': 899,
#          'planu': 895,
#          'trzy': 895,
#          'wymiany': 894,
#          'duża': 893,
#          'samochodów': 892,
#          '401k': 890,
#          'doświadczenie': 890,
#          'produkt': 889,
#          'sytuacja': 889,
#          'drugie': 886,
#          'długów': 886,
#          'sieci': 885,
#          'gdybym': 884,
#          'portfela': 883,
#          'powinienem': 882,
#          'dostać': 881,
#          'opłatę': 880,
#          'góry': 877,
#          'niewiele': 877,
#          'stać': 876,
#          'obu': 875,
#          's': 875,
#          'compose': 875,
#          'pracodawca': 875,
#          'euro': 873,
#          'llc': 872,
#          'sprzedawać': 871,
#          'klasy': 869,
#          'działalność': 868,
#          'upewnij': 868,
#          'sprawdź': 867,
#          'miała': 865,
#          'kiedyś': 865,
#          'dzisiaj': 865,
#          'wysokiej': 865,
#          'zrozumieć': 862,
#          'dać': 861,
#          'powód': 852,
#          'przepisy': 850,
#          'kluczowe': 849,
#          'kółko': 849,
#          'całe': 848,
#          'górę': 848,
#          'większej': 844,
#          'kupowanie': 844,
#          'zapłacisz': 844,
#          'wskaźnik': 843,
#          'większy': 838,
#          'wystarczy': 836,
#          'model': 836,
#          'złoto': 835,
#          'takiej': 834,
#          '65': 833,
#          'samej': 833,
#          'zarabiają': 828,
#          'inna': 827,
#          'szkoły': 827,
#          'wiki': 826,
#          'płacenia': 826,
#          'średniej': 825,
#          'skorzystać': 823,
#          'komentarze': 822,
#          'zdaniem': 822,
#          'odliczyć': 821,
#          'staje': 818,
#          'wybrać': 818,
#          'wydać': 818,
#          'szczególnie': 817,
#          'akcjami': 816,
#          'działają': 816,
#          'pierwszym': 815,
#          '2000': 814,
#          'jedno': 814,
#          'wybór': 814,
#          'rodziny': 813,
#          'ryzykiem': 813,
#          'coraz': 812,
#          'żadnej': 809,
#          'stanów': 809,
#          'opcję': 808,
#          'zawiera': 808,
#          'chwili': 808,
#          'zarabiać': 808,
#          'dotyczących': 806,
#          'opinie': 806,
#          'wzrośnie': 806,
#          'jednocześnie': 805,
#          'spada': 804,
#          'oferty': 803,
#          'jakieś': 802,
#          'zakupy': 802,
#          'wie': 801,
#          'pory': 797,
#          'znowu': 796,
#          'internetowej': 796,
#          'popyt': 795,
#          'decyzji': 795,
#          'rynki': 794,
#          'kredyty': 792,
#          'tymi': 792,
#          'zapewnić': 790,
#          'zdolność': 789,
#          'poziomu': 788,
#          ...})

# %%
import json
from collections import Counter

with open('counter.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

merged_frequency = Counter(data)
merged_frequency
# Out:
# Counter({'w': 177216,
#          'nie': 131898,
#          'i': 127683,
#          'na': 120509,
#          'to': 116794,
#          'z': 98105,
#          'jest': 94083,
#          'że': 90152,
#          'się': 86404,
#          'do': 67219,
#          'jeśli': 52297,
#          'a': 41496,
#          'ale': 41387,
#          'o': 38524,
#          'są': 35891,
#          'jak': 34827,
#          'lub': 33523,
#          'za': 32701,
#          'aby': 31262,
#          'co': 30180,
#          'od': 30179,
#          'może': 26581,
#          'dla': 25947,
#          'po': 25934,
#          'tak': 25711,
#          'które': 24104,
#          'możesz': 23314,
#          'czy': 22248,
#          'tego': 21981,
#          'tym': 21667,
#          'ma': 20395,
#          'być': 19356,
#          'ponieważ': 18963,
#          'przez': 17949,
#          'usd': 17614,
#          'tylko': 17346,
#          'więc': 17179,
#          'niż': 16949,
#          'ich': 14620,
#          'pieniądze': 14149,
#          'więcej': 13888,
#          'gdy': 13675,
#          'jako': 13167,
#          'pieniędzy': 12423,
#          'który': 12205,
#          'mogą': 11749,
#          'masz': 11722,
#          'będzie': 11718,
#          'akcji': 10970,
#          'firmy': 10925,
#          'również': 10538,
#          'bardzo': 10202,
#          'ci': 9988,
#          'prostu': 9805,
#          'nawet': 9745,
#          'lat': 9575,
#          'mają': 9348,
#          '>': 9332,
#          'wiele': 9243,
#          'ten': 9012,
#          'te': 8807,
#          'ze': 8725,
#          'kiedy': 8704,
#          'akcje': 8524,
#          'bez': 8406,
#          'teraz': 8129,
#          'roku': 8102,
#          'prawdopodobnie': 8045,
#          'jesteś': 7936,
#          'przypadku': 7837,
#          'bardziej': 7798,
#          'ludzie': 7786,
#          'naprawdę': 7781,
#          'która': 7732,
#          'sposób': 7632,
#          'dolarów': 7585,
#          'można': 7574,
#          'twoje': 7545,
#          '000': 7479,
#          'pracy': 7346,
#          '1': 7305,
#          'go': 7250,
#          'sobie': 7207,
#          'tych': 7185,
#          'musisz': 7102,
#          '10': 7074,
#          'będziesz': 6916,
#          'je': 6886,
#          'chcesz': 6833,
#          'mieć': 6813,
#          'tej': 6804,
#          'jestem': 6716,
#          'jednak': 6709,
#          'pod': 6674,
#          'już': 6541,
#          'nadal': 6522,
#          'twój': 6512,
#          'rzeczy': 6447,
#          'firma': 6375,
#          'którzy': 6371,
#          'których': 6326,
#          'wszystkie': 6272,
#          'kilka': 6241,
#          'będą': 6149,
#          'wartość': 6082,
#          'mniej': 5998,
#          'swoje': 5930,
#          'rynku': 5858,
#          'przed': 5816,
#          'wszystko': 5799,
#          'stanie': 5774,
#          'ludzi': 5771,
#          'wartości': 5714,
#          'oznacza': 5622,
#          'mi': 5556,
#          'usa': 5537,
#          'r': 5536,
#          '2': 5520,
#          'większość': 5514,
#          'innych': 5472,
#          'mam': 5460,
#          'coś': 5453,
#          'inne': 5344,
#          'zrobić': 5332,
#          '100': 5293,
#          'było': 5265,
#          'przykład': 5169,
#          'następnie': 5167,
#          'ceny': 5165,
#          'konto': 5079,
#          'domu': 5078,
#          'przy': 5059,
#          'ile': 5039,
#          'dlaczego': 5007,
#          'itp': 5006,
#          'takie': 5002,
#          'jego': 4981,
#          'czasu': 4939,
#          'którym': 4925,
#          'wielu': 4912,
#          'znacznie': 4861,
#          'myślę': 4745,
#          'nigdy': 4660,
#          'podatku': 4637,
#          'istnieje': 4626,
#          'był': 4572,
#          'sprzedaży': 4561,
#          'czas': 4547,
#          'nich': 4535,
#          'swoich': 4496,
#          'konta': 4486,
#          'cię': 4486,
#          '5': 4465,
#          'mnie': 4445,
#          'dużo': 4442,
#          'uzyskać': 4421,
#          'około': 4411,
#          'dobrze': 4409,
#          '3': 4401,
#          'ciebie': 4400,
#          'zawsze': 4354,
#          'cena': 4247,
#          'podczas': 4210,
#          'wszystkich': 4195,
#          'kredytu': 4186,
#          '=': 4180,
#          'dlatego': 4137,
#          'którą': 4127,
#          'powinieneś': 4095,
#          'jaki': 4090,
#          'im': 4087,
#          'osób': 4079,
#          'bank': 4059,
#          'też': 3997,
#          'pożyczki': 3925,
#          'ciągu': 3914,
#          'dochód': 3902,
#          'nic': 3867,
#          'karty': 3853,
#          'mogę': 3833,
#          '20': 3810,
#          'trochę': 3809,
#          'twoja': 3801,
#          'oczywiście': 3773,
#          'wydaje': 3768,
#          'prawie': 3755,
#          'ryzyko': 3754,
#          'gdzie': 3751,
#          '$': 3735,
#          'każdy': 3729,
#          'uwagę': 3720,
#          'jej': 3709,
#          'nieruchomości': 3694,
#          'zwykle': 3691,
#          'płatności': 3678,
#          'rynek': 3672,
#          'ta': 3667,
#          'część': 3642,
#          'między': 3588,
#          'której': 3577,
#          'zamiast': 3541,
#          'tutaj': 3540,
#          'kupić': 3539,
#          'ira': 3529,
#          'dom': 3488,
#          'inwestycji': 3466,
#          'powodu': 3459,
#          'banku': 3436,
#          'by': 3428,
#          'podatki': 3416,
#          'chociaż': 3398,
#          'pytanie': 3395,
#          'twoim': 3392,
#          'ktoś': 3384,
#          'poza': 3380,
#          'chodzi': 3364,
#          'twojego': 3351,
#          'zbyt': 3341,
#          'kto': 3333,
#          'wtedy': 3289,
#          'często': 3282,
#          'gdyby': 3246,
#          'podatek': 3239,
#          'ani': 3223,
#          'tam': 3201,
#          'niektóre': 3184,
#          'musi': 3183,
#          'zapłacić': 3172,
#          'którego': 3171,
#          'twojej': 3146,
#          'celu': 3126,
#          'tę': 3115,
#          'kredyt': 3104,
#          'jeszcze': 3099,
#          'byłoby': 3091,
#          '50': 3071,
#          'fundusze': 3064,
#          'firm': 3061,
#          'należy': 3054,
#          'koszty': 3026,
#          'albo': 3026,
#          '30': 3002,
#          'była': 2983,
#          'opcji': 2980,
#          'problem': 2911,
#          'tys': 2910,
#          'samo': 2908,
#          'opłaty': 2907,
#          'temat': 2905,
#          'takich': 2879,
#          'znaleźć': 2876,
#          'zostanie': 2875,
#          'także': 2874,
#          'lepiej': 2872,
#          'wszyscy': 2865,
#          'podatków': 2858,
#          'pracę': 2849,
#          'biorąc': 2840,
#          'dość': 2838,
#          'miał': 2829,
#          'jeden': 2813,
#          'wysokości': 2789,
#          'wydatki': 2779,
#          'zwrot': 2766,
#          'transakcji': 2752,
#          'rok': 2745,
#          'były': 2744,
#          'jakie': 2741,
#          'wynosi': 2731,
#          'odsetki': 2731,
#          'ty': 2726,
#          'strony': 2725,
#          '4': 2719,
#          'fundusz': 2700,
#          'wiem': 2684,
#          'moje': 2680,
#          'rzeczywistości': 2677,
#          'każdego': 2670,
#          'musiał': 2665,
#          'rząd': 2660,
#          'swoim': 2655,
#          'muszą': 2650,
#          'ryzyka': 2645,
#          'swojego': 2643,
#          'banki': 2639,
#          'pewien': 2639,
#          'czasie': 2635,
#          'swoją': 2630,
#          'sam': 2625,
#          'swój': 2596,
#          '15': 2591,
#          'one': 2581,
#          'zyski': 2572,
#          'dywidendy': 2572,
#          'zysków': 2551,
#          'rzecz': 2542,
#          'cenę': 2539,
#          'swojej': 2508,
#          'płacić': 2497,
#          'kosztów': 2488,
#          'oraz': 2483,
#          'osoby': 2461,
#          'oszczędności': 2454,
#          'ją': 2439,
#          '|': 2430,
#          'mój': 2425,
#          'ponad': 2423,
#          'samochód': 2423,
#          'zostać': 2421,
#          'kredytowej': 2412,
#          'żadnych': 2401,
#          'chcą': 2393,
#          'dzięki': 2391,
#          'momencie': 2390,
#          'dochodu': 2389,
#          'istnieją': 2384,
#          'dwa': 2375,
#          'zazwyczaj': 2375,
#          'potrzebujesz': 2364,
#          'zależy': 2364,
#          'innego': 2362,
#          'inny': 2360,
#          'wzrost': 2346,
#          'odpowiedź': 2346,
#          'sytuacji': 2330,
#          'dług': 2327,
#          'jednym': 2304,
#          'kapitału': 2297,
#          'czego': 2291,
#          'informacji': 2285,
#          'całkowicie': 2285,
#          'gotówki': 2283,
#          'kwotę': 2275,
#          'temu': 2273,
#          'moim': 2264,
#          'mówi': 2263,
#          'obecnie': 2262,
#          'koszt': 2260,
#          'ubezpieczenie': 2259,
#          'wystarczająco': 2255,
#          'miesięcy': 2253,
#          'rocznie': 2250,
#          'zysk': 2245,
#          'dokładnie': 2243,
#          'odsetek': 2243,
#          'aktywów': 2242,
#          'funduszu': 2239,
#          'dnia': 2238,
#          'zwrotu': 2236,
#          'pracowników': 2226,
#          'kilku': 2220,
#          'obligacji': 2213,
#          'cały': 2209,
#          'działa': 2203,
#          'płacisz': 2194,
#          'chyba': 2194,
#          'zależności': 2191,
#          'hipotecznego': 2186,
#          'względu': 2181,
#          'sprzedać': 2180,
#          'opodatkowaniu': 2180,
#          'zanim': 2170,
#          'dobre': 2169,
#          'funduszy': 2151,
#          'twoich': 2150,
#          'usługi': 2148,
#          'przynajmniej': 2147,
#          'kraju': 2140,
#          'każdym': 2133,
#          'właśnie': 2120,
#          'powiedzieć': 2111,
#          'etf': 2105,
#          'razie': 2104,
#          '500': 2100,
#          'dotyczące': 2091,
#          'życie': 2090,
#          '6': 2078,
#          'dobry': 2066,
#          'większości': 2063,
#          'lata': 2061,
#          'różne': 2054,
#          'różnych': 2052,
#          'sprzedaż': 2051,
#          'chce': 2049,
#          'tyle': 2040,
#          'kwoty': 2037,
#          'zasadniczo': 2033,
#          'życia': 2031,
#          'danych': 2031,
#          'korzyści': 2023,
#          'faktycznie': 2018,
#          'możliwe': 2010,
#          'dopóki': 2005,
#          'obligacje': 2003,
#          'osoba': 1999,
#          'ja': 1985,
#          'poziomie': 1985,
#          'irs': 1978,
#          'wygląda': 1974,
#          'koncie': 1966,
#          'jedną': 1962,
#          'nad': 1959,
#          'dni': 1956,
#          'moja': 1949,
#          'dochodów': 1947,
#          'liczby': 1947,
#          'duże': 1947,
#          'wydatków': 1943,
#          'odpowiedzi': 1940,
#          'firmę': 1940,
#          'np': 1938,
#          'innym': 1936,
#          'ogólnie': 1933,
#          'samochodu': 1926,
#          'miejsce': 1913,
#          'oto': 1899,
#          'części': 1890,
#          'mojego': 1882,
#          'podatkowe': 1872,
#          'stopy': 1866,
#          'opcje': 1862,
#          'świecie': 1862,
#          'powinien': 1856,
#          'rodzaju': 1854,
#          '25': 1853,
#          'twoją': 1841,
#          'zgodnie': 1835,
#          'ponownie': 1827,
#          'informacje': 1824,
#          'powiedzmy': 1819,
#          'netto': 1816,
#          'stawki': 1816,
#          'stronie': 1804,
#          'żeby': 1804,
#          'poniżej': 1801,
#          'wcześniej': 1793,
#          'nikt': 1792,
#          'system': 1792,
#          'nieco': 1789,
#          'samym': 1788,
#          'niektórych': 1783,
#          'taki': 1776,
#          'szybko': 1767,
#          'końcu': 1764,
#          'mógł': 1763,
#          'nadzieję': 1759,
#          'według': 1753,
#          'pożyczkę': 1747,
#          'e': 1744,
#          'zarówno': 1744,
#          'online': 1743,
#          'najbardziej': 1743,
#          'później': 1741,
#          'roth': 1735,
#          'powyżej': 1733,
#          'cenie': 1732,
#          'polega': 1730,
#          'cen': 1729,
#          'pamiętaj': 1728,
#          'porównaniu': 1726,
#          '1000': 1718,
#          'mówiąc': 1716,
#          'on': 1715,
#          'zwłaszcza': 1702,
#          'potem': 1699,
#          'firmie': 1697,
#          'klientów': 1682,
#          'zakupu': 1676,
#          'uważam': 1666,
#          'ubezpieczenia': 1666,
#          'bezpośrednio': 1665,
#          'mamy': 1664,
#          'mojej': 1661,
#          'koniec': 1657,
#          'dzieci': 1656,
#          'jednego': 1655,
#          'brzmi': 1651,
#          'został': 1651,
#          'prawo': 1651,
#          'wypłaty': 1650,
#          'inwestycje': 1649,
#          'niektórzy': 1649,
#          'miesięcznie': 1638,
#          'powinno': 1636,
#          'kredytową': 1636,
#          'emeryturę': 1635,
#          'raz': 1634,
#          'lepsze': 1631,
#          'dzieje': 1628,
#          'zakup': 1627,
#          'hipoteczny': 1621,
#          'kwota': 1621,
#          'inni': 1619,
#          'czym': 1618,
#          'miesiąc': 1616,
#          'x': 1616,
#          'dane': 1609,
#          'nas': 1608,
#          'robią': 1608,
#          'miejsca': 1607,
#          'procent': 1606,
#          'przyszłości': 1604,
#          'daje': 1602,
#          'łatwo': 1591,
#          'wiesz': 1588,
#          'pomóc': 1577,
#          'niezależnie': 1563,
#          'robi': 1561,
#          'podstawie': 1555,
#          'artykuł': 1553,
#          'wzrostu': 1552,
#          'wyższe': 1552,
#          'handlu': 1551,
#          'tj': 1549,
#          'usług': 1540,
#          'razy': 1536,
#          'posiadanie': 1534,
#          'zostały': 1533,
#          'robić': 1532,
#          'amazon': 1526,
#          'podobnie': 1523,
#          'siebie': 1522,
#          'nowy': 1522,
#          'zjednoczonych': 1519,
#          'razem': 1519,
#          'taka': 1515,
#          'google': 1515,
#          'aktywa': 1514,
#          'dotyczy': 1509,
#          'poprzez': 1505,
#          'kapitał': 1504,
#          'zysku': 1502,
#          'zobaczyć': 1499,
#          '+': 1496,
#          'jakiś': 1474,
#          'ponadto': 1471,
#          'drugiej': 1453,
#          'innymi': 1452,
#          'opłat': 1449,
#          'kogoś': 1447,
#          'saldo': 1446,
#          '40': 1446,
#          'prawda': 1445,
#          'prawa': 1445,
#          'pierwsze': 1434,
#          'możliwości': 1434,
#          'pomysł': 1432,
#          'dodatkowe': 1430,
#          'wymaga': 1429,
#          'długu': 1429,
#          'powiedział': 1428,
#          'wpływ': 1425,
#          'takim': 1419,
#          'takiego': 1417,
#          'najlepsze': 1412,
#          'najmniej': 1409,
#          'zainwestować': 1408,
#          'nowe': 1401,
#          'pomocą': 1399,
#          'dwóch': 1398,
#          'pytania': 1397,
#          'dalej': 1396,
#          'czasami': 1395,
#          'latach': 1394,
#          'ogóle': 1394,
#          'jaką': 1392,
#          'podatkowych': 1388,
#          'spłacić': 1386,
#          'plan': 1386,
#          'mówisz': 1382,
#          'b': 1381,
#          'pewnością': 1380,
#          'kartę': 1377,
#          'rozumiem': 1377,
#          'chcę': 1377,
#          'we': 1370,
#          'zgadzam': 1369,
#          'dzień': 1369,
#          'sądzę': 1364,
#          'umowy': 1360,
#          'warto': 1359,
#          'pozwolić': 1359,
#          'okresie': 1356,
#          'każda': 1352,
#          'dużej': 1352,
#          'praca': 1349,
#          'inwestorów': 1349,
#          'czek': 1347,
#          'myśli': 1340,
#          'każdej': 1339,
#          'biznes': 1334,
#          'pozwala': 1334,
#          'dochody': 1329,
#          '12': 1326,
#          'u': 1326,
#          'pożyczek': 1322,
#          'ważne': 1317,
#          'gotówkę': 1311,
#          'wszelkie': 1309,
#          'zasady': 1303,
#          '0': 1303,
#          'warte': 1302,
#          'jedna': 1301,
#          'brak': 1297,
#          'k': 1296,
#          'możliwość': 1295,
#          'całkiem': 1294,
#          'banków': 1294,
#          '7': 1293,
#          'sposobem': 1292,
#          'wieku': 1290,
#          'zakładając': 1286,
#          'jednej': 1286,
#          'kredytowe': 1285,
#          'kont': 1283,
#          'kart': 1280,
#          'mu': 1276,
#          'zdecydowanie': 1275,
#          'rachunku': 1271,
#          'długo': 1271,
#          'środków': 1269,
#          'oprocentowanie': 1266,
#          'bo': 1257,
#          'okres': 1256,
#          'czegoś': 1254,
#          'zasadzie': 1252,
#          'prawdopodobne': 1250,
#          'osobiście': 1250,
#          'godzin': 1249,
#          'kredytów': 1249,
#          'niego': 1249,
#          'straty': 1248,
#          'wziąć': 1247,
#          'moich': 1246,
#          'zadłużenia': 1246,
#          'zostaną': 1245,
#          'oni': 1244,
#          'podatkowym': 1243,
#          'problemy': 1238,
#          'same': 1234,
#          '8': 1234,
#          'powinna': 1232,
#          'powodów': 1228,
#          'widzę': 1227,
#          'kupować': 1226,
#          'wyniki': 1226,
#          'płacą': 1225,
#          'inwestorzy': 1224,
#          'otrzymasz': 1223,
#          'wszystkim': 1222,
#          'stanach': 1216,
#          'kupujesz': 1212,
#          'dwie': 1206,
#          'płaci': 1205,
#          'najpierw': 1203,
#          'została': 1203,
#          'trudno': 1202,
#          'spłaty': 1201,
#          'najlepszy': 1200,
#          'możemy': 1197,
#          'cóż': 1196,
#          'pracodawcy': 1195,
#          'wraz': 1190,
#          'nimi': 1185,
#          'oferuje': 1184,
#          'składki': 1181,
#          'pierwszy': 1181,
#          'znaczenia': 1179,
#          'liczba': 1179,
#          'powinny': 1178,
#          'nowego': 1177,
#          'kupna': 1175,
#          'otrzymujesz': 1168,
#          'wykorzystać': 1167,
#          'miejscu': 1166,
#          'kredytowych': 1165,
#          'sprawę': 1165,
#          'branży': 1164,
#          'byłaby': 1162,
#          'giełdzie': 1162,
#          'związane': 1161,
#          'inaczej': 1160,
#          'punktu': 1158,
#          'byłby': 1154,
#          'wciąż': 1150,
#          'miałem': 1149,
#          'finansowych': 1146,
#          'większe': 1146,
#          'fakt': 1145,
#          'dobra': 1142,
#          'wielkiej': 1142,
#          'duży': 1142,
#          'wysokie': 1138,
#          'niskie': 1137,
#          'rzeczą': 1136,
#          'nowych': 1134,
#          'jakości': 1133,
#          'rachunek': 1132,
#          'żadnego': 1132,
#          'dobrym': 1129,
#          '401(k': 1127,
#          'inną': 1125,
#          'zarobić': 1121,
#          '200': 1117,
#          'środki': 1117,
#          'nim': 1117,
#          'dostępne': 1114,
#          'ilość': 1110,
#          'mieli': 1110,
#          'podatkowego': 1109,
#          'generalnie': 1108,
#          'zmiany': 1108,
#          'pewne': 1105,
#          'byli': 1105,
#          'najlepiej': 1103,
#          'pracować': 1101,
#          'wiedzieć': 1100,
#          'aż': 1099,
#          'autotldr': 1098,
#          'stopa': 1097,
#          'ramach': 1096,
#          'początku': 1093,
#          'właściwie': 1093,
#          'numer': 1092,
#          'sens': 1091,
#          'różnica': 1090,
#          'pewno': 1086,
#          'uniknąć': 1083,
#          'własne': 1081,
#          'pośrednictwem': 1078,
#          'porządku': 1076,
#          'myślisz': 1076,
#          'stosunku': 1075,
#          'typu': 1074,
#          'transakcje': 1073,
#          'powodem': 1071,
#          'problemem': 1071,
#          'przeciwko': 1069,
#          'ilości': 1067,
#          'finansowe': 1066,
#          'kapitałowych': 1063,
#          'dużą': 1063,
#          'historii': 1061,
#          '60': 1060,
#          'najlepszym': 1059,
#          'czyli': 1059,
#          'użyć': 1058,
#          'jesteśmy': 1056,
#          'pieniędzmi': 1054,
#          'otrzymać': 1053,
#          '90': 1051,
#          'jedynym': 1050,
#          'doświadczenia': 1050,
#          'głównie': 1047,
#          'salda': 1047,
#          'robisz': 1047,
#          'akcję': 1045,
#          'dostęp': 1045,
#          'pożyczka': 1045,
#          'problemu': 1044,
#          'rację': 1043,
#          'sprawia': 1043,
#          'mało': 1041,
#          'inwestowanie': 1038,
#          'inwestycyjne': 1036,
#          'załóżmy': 1036,
#          'domów': 1031,
#          'zostało': 1030,
#          'ostatnich': 1029,
#          'inwestycja': 1029,
#          'cokolwiek': 1029,
#          'dobrą': 1028,
#          '401': 1027,
#          'umiejętności': 1026,
#          'działalności': 1026,
#          'produktów': 1026,
#          'będę': 1026,
#          'produkty': 1025,
#          'udział': 1022,
#          'klienta': 1022,
#          'byłem': 1022,
#          'plus': 1020,
#          'pozycji': 1018,
#          's&p': 1015,
#          'kiedykolwiek': 1014,
#          'brytanii': 1013,
#          'właścicielem': 1012,
#          'winien': 1012,
#          'opcja': 1011,
#          'inflacji': 1010,
#          'apple': 1009,
#          'słowa': 1009,
#          'rachunki': 1007,
#          'miejsc': 1006,
#          'muszę': 1006,
#          'zobacz': 1006,
#          'celem': 1006,
#          'systemu': 1006,
#          '80': 1006,
#          'dużych': 1004,
#          'trzeba': 1003,
#          'strona': 1002,
#          'mogłem': 1002,
#          'zakresie': 1000,
#          'waluty': 999,
#          'milionów': 998,
#          'stany': 997,
#          'zacząć': 994,
#          'zaoszczędzić': 992,
#          'abyś': 991,
#          'jaka': 988,
#          'samego': 986,
#          'rządu': 986,
#          'stronę': 986,
#          'pomoże': 984,
#          'punkt': 984,
#          'pracownicy': 983,
#          'złota': 983,
#          'płatność': 982,
#          'innej': 980,
#          'mówię': 978,
#          'złe': 976,
#          'przypadkach': 975,
#          'kosztuje': 975,
#          'ostatecznie': 974,
#          'wyjątkiem': 974,
#          'uważasz': 972,
#          'mimo': 972,
#          'trudne': 972,
#          'handel': 970,
#          'widzenia': 970,
#          'zwroty': 970,
#          'nasze': 970,
#          'celów': 969,
#          'inwestować': 965,
#          'sprawdzić': 964,
#          'tu': 960,
#          'długi': 959,
#          'mogli': 958,
#          'c': 955,
#          'miesiąca': 955,
#          'samą': 955,
#          'gdybyś': 954,
#          'spółki': 954,
#          'procentowe': 954,
#          'ludziom': 954,
#          'nieruchomość': 953,
#          'jasne': 950,
#          'związku': 949,
#          'gospodarki': 946,
#          'inwestowania': 946,
#          'powrotem': 945,
#          'problemów': 944,
#          'stawka': 943,
#          'liczbę': 939,
#          'tobą': 937,
#          'bankowe': 937,
#          'sama': 935,
#          'taką': 935,
#          'potrzeby': 933,
#          'rodzaj': 930,
#          'częścią': 929,
#          'większą': 928,
#          'podobne': 925,
#          'zapewnia': 925,
#          'biznesu': 925,
#          'przeciwnym': 924,
#          'obejmuje': 924,
#          'własny': 924,
#          'znajduje': 923,
#          'utrzymać': 923,
#          'chciałbym': 923,
#          'inwestycyjnych': 922,
#          'mówią': 921,
#          'poziom': 921,
#          'całym': 920,
#          'dowiedzieć': 920,
#          'dolara': 918,
#          'znam': 917,
#          'czynsz': 917,
#          'własnego': 915,
#          'the': 914,
#          'zmienić': 911,
#          'spłatę': 910,
#          'powinni': 909,
#          'message': 909,
#          'widziałem': 909,
#          'wynik': 908,
#          'nam': 908,
#          'proces': 906,
#          'ona': 905,
#          'badania': 901,
#          'źle': 901,
#          'pewnym': 901,
#          'limit': 901,
#          'finansów': 900,
#          'niższe': 899,
#          'planu': 895,
#          'trzy': 895,
#          'wymiany': 894,
#          'duża': 893,
#          'samochodów': 892,
#          '401k': 890,
#          'doświadczenie': 890,
#          'produkt': 889,
#          'sytuacja': 889,
#          'drugie': 886,
#          'długów': 886,
#          'sieci': 885,
#          'gdybym': 884,
#          'portfela': 883,
#          'powinienem': 882,
#          'dostać': 881,
#          'opłatę': 880,
#          'góry': 877,
#          'niewiele': 877,
#          'stać': 876,
#          'obu': 875,
#          's': 875,
#          'compose': 875,
#          'pracodawca': 875,
#          'euro': 873,
#          'llc': 872,
#          'sprzedawać': 871,
#          'klasy': 869,
#          'działalność': 868,
#          'upewnij': 868,
#          'sprawdź': 867,
#          'miała': 865,
#          'kiedyś': 865,
#          'dzisiaj': 865,
#          'wysokiej': 865,
#          'zrozumieć': 862,
#          'dać': 861,
#          'powód': 852,
#          'przepisy': 850,
#          'kluczowe': 849,
#          'kółko': 849,
#          'całe': 848,
#          'górę': 848,
#          'większej': 844,
#          'kupowanie': 844,
#          'zapłacisz': 844,
#          'wskaźnik': 843,
#          'większy': 838,
#          'wystarczy': 836,
#          'model': 836,
#          'złoto': 835,
#          'takiej': 834,
#          '65': 833,
#          'samej': 833,
#          'zarabiają': 828,
#          'inna': 827,
#          'szkoły': 827,
#          'wiki': 826,
#          'płacenia': 826,
#          'średniej': 825,
#          'skorzystać': 823,
#          'komentarze': 822,
#          'zdaniem': 822,
#          'odliczyć': 821,
#          'staje': 818,
#          'wybrać': 818,
#          'wydać': 818,
#          'szczególnie': 817,
#          'akcjami': 816,
#          'działają': 816,
#          'pierwszym': 815,
#          '2000': 814,
#          'jedno': 814,
#          'wybór': 814,
#          'rodziny': 813,
#          'ryzykiem': 813,
#          'coraz': 812,
#          'żadnej': 809,
#          'stanów': 809,
#          'opcję': 808,
#          'zawiera': 808,
#          'chwili': 808,
#          'zarabiać': 808,
#          'dotyczących': 806,
#          'opinie': 806,
#          'wzrośnie': 806,
#          'jednocześnie': 805,
#          'spada': 804,
#          'oferty': 803,
#          'jakieś': 802,
#          'zakupy': 802,
#          'wie': 801,
#          'pory': 797,
#          'znowu': 796,
#          'internetowej': 796,
#          'popyt': 795,
#          'decyzji': 795,
#          'rynki': 794,
#          'kredyty': 792,
#          'tymi': 792,
#          'zapewnić': 790,
#          'zdolność': 789,
#          'poziomu': 788,
#          ...})

# %%
import json

with open('./counter.json', 'w') as f:
    json.dump(merged_frequency, f)

# %% [markdown]
# # 3) Applying distortion to queries

# %%
polish_letters = [
    'a', 'ą', 'b', 'c', 'ć', 'd', 'e', 'ę', 'f', 'g', 'h', 'i', 'j', 'k',
    'l', 'ł', 'm', 'n', 'ń', 'o', 'ó', 'p', 'q', 'r', 's', 'ś', 't', 'u',
    'v', 'w', 'x', 'y', 'z', 'ź', 'ż'
]

# %%
import random

def distortion(word):

  choice= random.randint(0, 2)

  n = len(word)
  random_id = random.randint(0, n-1)

  random_letter = random.choice(polish_letters)

  if choice == 0:
    ##remove random letter
    return word[:random_id] + word[random_id + 1:]
  if choice == 1:
    #add random letter
    return word[:random_id] + random_letter + word[random_id:]

  if choice == 2:
    #replace random letter
    return word[:random_id] + random_letter + word[random_id + 1:]

# %%
random.seed(2137)

# %%
distort_counter = Counter()
distort_list = []
indexes_list = []
correct_list = []

for sentence in queries:
  tokens = nlp(sentence["text"])
  tokens = [token.text.lower() for token in tokens if not token.is_punct and not token.is_space]
  n = len(tokens)
  random_id = random.randint(0, n-1)
  empty_list = []
  for i in range(n):
    if i == random_id:
      word = distortion(tokens[i])
      correct_list.append(tokens[i])
    else:
      word = tokens[i]
    distort_counter[word] += 1
    empty_list.append(word)
  indexes_list.append(sentence['_id'])

  distort_list.append(empty_list)

# %%
print(distort_list[2137])
print(correct_list[2137])
print(indexes_list[2137])
# Out:
# ['dlaczego', 'domy', 'rausch', 'colemana', 'są', 'tak', 'tanie', 'czy', 'to', 'dlatego', 'e', 'nie', 'mają', 'gazu']
# że
# 4002

# %% [markdown]
# # 4) Baseline ndcg

# %% [markdown]
# #### Preparing elastic search client

# %%
from elasticsearch import Elasticsearch

link = 'http://localhost:9200/'

es = Elasticsearch(link)
es
# Out:
# <Elasticsearch(['http://localhost:9200'])>

# %% [markdown]
# #### Elastic search index

# %%
index_config_lamentizer = {
  "settings": {
    "analysis": {
      "analyzer": {
        "polish_with_synonyms_with_lam": {
          "tokenizer": "standard",
          "filter": [
            "lowercase",
            "morfologik_stem",
            "lowercase"
          ]
        },
        "polish_with_synonyms_without_lam": {
          "tokenizer": "standard",
          "filter": [
            "lowercase",
            "morfologik_stem",
          ]
        },
        "polish_without_synonyms_with_lam": {
          "tokenizer": "standard",
          "filter": [
            "lowercase",
            "lowercase",
          ]
        },
        "polish_without_synonyms_without_lam": {
          "tokenizer": "standard",
          "filter": [
            "lowercase",
          ]
        }
      },
    }
  },
  "mappings": {
    "properties": {
      "answer_with_synonyms_with_lam": {
        "type": "text",
        "analyzer": "polish_with_synonyms_with_lam"
      },
      "answer_with_synonyms_without_lam": {
        "type": "text",
        "analyzer": "polish_with_synonyms_without_lam"
      },
      "answer_without_synonyms_with_lam": {
        "type": "text",
        "analyzer": "polish_without_synonyms_with_lam"
      },
      "answer_without_synonyms_without_lam": {
        "type": "text",
        "analyzer": "polish_without_synonyms_without_lam"
      }
    }
  }
}

# %% [markdown]
# #### Indexing dataset

# %%
index_name = 'biore_sie_do_roboty'

# %%
def generate_docs(ds):
    for doc in ds:
        yield {
            "_index": index_name,
            "_id": doc["_id"],
            "_source": {
                "answer_with_synonyms_with_lam": doc["text"],
                "answer_with_synonyms_without_lam": doc["text"],
                "answer_without_synonyms_with_lam": doc['text'],
                "answer_without_synonyms_without_lam": doc['text']
            }
        }

# %%
from elasticsearch import helpers

es.options(ignore_status=[400, 404]).indices.delete(index=index_name)
es.indices.create(index=index_name, body=index_config_lamentizer)

try:
    success, errors = helpers.bulk(es, generate_docs(corpus))
    
    print(f"Successfully indexed {success} documents")
    if errors:
        print(f"Errors during indexing: {errors}")
        
except Exception as e:
    print(f"Error during bulk indexing: {e}")
# Out:
# Successfully indexed 57638 documents

# %% [markdown]
# #### Preparing queries to corpus relation dictionary

# %%
from collections import defaultdict

corpus_list = []
queries_list = []
query_to_corpus = defaultdict(list)

for query_id, corpus_id in zip(train["query-id"], train["corpus-id"]):
    query_to_corpus[query_id].append(corpus_id)
    queries_list.append(query_id)
    corpus_list.append(corpus_id)
print("Done train")

for query_id, corpus_id in zip(test["query-id"], test["corpus-id"]):
    query_to_corpus[query_id].append(corpus_id)
    queries_list.append(query_id)
    corpus_list.append(corpus_id)
print("Done test")

for query_id, corpus_id in zip(validation["query-id"], validation["corpus-id"]):
    query_to_corpus[query_id].append(corpus_id)
    queries_list.append(query_id)
    corpus_list.append(corpus_id)
print("Done validation")

query_to_corpus = dict(query_to_corpus)
# Out:
# Done train
# Done test
# Done validation

# %%
corpus_dict = defaultdict(list)

for item in corpus:
  if int(item['_id']) in corpus_list:
    corpus_dict[int(item['_id'])].append(item['text'])

corpus_dict = dict(corpus_dict)

# %%
queries_dict = defaultdict(list)

for item in queries:
  if int(item['_id']) in queries_list:
    queries_dict[int(item['_id'])].append(item['text'])

queries_dict = dict(queries_dict)

# %%
index = 4002
print(queries_dict[index])
for i in query_to_corpus[index]:
  print(corpus_dict[i])
# Out:
# ['Dlaczego domy Rausch Colemana są tak tanie? Czy to dlatego, że nie mają gazu?']
# ['„W północno-zachodnim Arkansas większość domów oferowanych przez tę firmę kosztuje około 90-110 dolarów za stopę kwadratową. Wyjątkiem jest plan Whitney, który ma następujące cechy konstrukcyjne (i/lub problemy), które znacznie oszczędzają budowniczemu pieniędzy: Jedną z bardzo fajnych funkcji są schody w kształcie litery U pośrodku domu. Łatwo je znaleźć i ma podest. Może być jednak nieco wąski. Czy budowniczy zadaje sobie trud, aby umieścić pręt zbrojeniowy w cegła? Arkansas znajduje się w kraju trzęsienia ziemi. Jakie są podłogi? Czy pierwsze piętro jest płytą betonową posadzką z winylową podłogą (i/lub dywanem na cienkiej podkładce) bezpośrednio nad betonem? Czy drugie piętro jest sprężyste z powodu span legary o minimalnym rozmiarze kodu? Czy konstruktor zadaje sobie trud, aby tylne okna wyglądały tak ładnie jak przednie? Jak wspomniano wcześniej, budowniczy zadaje sobie trud, aby mieć tylko jedno okno boczne. Gdzie dowiedzieć się więcej: Fernando Pagés Ruiz pochodzi z Nebraski budowniczy domu, który napisał książkę o budowaniu przystępnej ceny e House: Tajemnice handlowe dla budownictwa o wysokiej wartości i niskich kosztach (The Taunton Press, 2005). Napisał również wiele artykułów w Fine Homebuilding, w tym „Budowanie niedrogich domów”. True North Consulting specjalizuje się w pomaganiu budowniczym w eliminowaniu odpadów i „inżynierii wartości” w ich projektach. True North często współpracuje z Timem Garrisonem, samozwańczym „inżynierem budowlanym”.”.']
# ['25% różnica w cenie na większości rynków nie jest tak szalona, \u200b\u200baby wymagać od niej jakiegoś okropnego oszustwa, ale to nie znaczy wiele więcej. Może to być uwzględnienie planów pięter, które są starannie zaprojektowane, aby dodać powierzchnię kwadratową przy minimalnych kosztach, a tym samym zmniejszyć średni koszt na stopę kwadratową, nie będąc w rzeczywistości tańszym, mniej izolacji, cieńsze ściany, tanie orurowanie, zminimalizowane okablowanie, lub po prostu wydajny i konkurencyjny. Jak wspomniałeś, nie mają gazu, więc jest to z pewnością jeden ze sposobów, w jaki wiesz, że obniżają koszty - nie ma przewodów gazowych do zainstalowania! Jak wskazuje artykuł z NAHB: Koszt budowy domu, to, co obejmuje ta liczba, może się różnić. Czy obejmuje gotową partię? Jeśli tak, to mniejsza działka oznaczałaby niższą cenę powierzchni zabudowy - bo grunt jest mniejszy i tańszy, a nie dom! Czy w cenie podane jest jakiekolwiek finansowanie? Porównaj także koszty zmiany planu, wszelkie kary za opóźnienia w budowie, klasę materiałów, plany pięter, koszty dostosowywania, opłaty lub premie za wybór kolorów/podłóg/lad/szafek/osprzętu i tak dalej. A co z centralnym chłodzeniem i ogrzewaniem - czy mówią o piecu elektrycznym? Jak ogrzewanie elektryczne w Twojej okolicy ma się do kosztów ogrzewania gazowego? (Względne ceny energii elektrycznej i gazu różnią się znacznie w zależności od regionu i klimatu) W skrócie: często cena za metr kwadratowy to nie wszystko, ile kosztowałoby wybudowanie domu. Upewnij się, że porównujesz wszystko, co jest dla Ciebie ważne, i otrzymujesz pełną wycenę, a nie porównując małe, pojedyncze dane dotyczące sprzedaży bez wyraźnych szczegółów. Jeśli okaże się, że cena jest o 25% niższa niż w przypadku innych budowniczych w Twojej okolicy, a oni dają Ci to, czego chcesz, i masz dobry rozsądek, aby wykwalifikowany inspektor budowlany i / lub inżynier budowlany dokładnie sprawdzili dom, zanim przejmiesz go w posiadanie , być może właśnie znalazłeś dobrego konstruktora! Zachęcam Cię do osobistego odwiedzenia niektórych z ich wcześniejszych prac budowlanych, takich jak domy, które zbudowali 2-10 lat temu i upewnienia się, że są w takim stanie, jakiego można się spodziewać.']
# ['Jestem pośrednikiem w handlu nieruchomościami i pracuję dla Rauscha Colemana i mogę odpowiedzieć na to pytanie za Ciebie. Jesteśmy budowniczym produkcji. Budujemy społeczności z typowymi opcjami 5-9 Floorplan na społeczność oraz wybranym zestawem opcji i wykończeń, które oferujemy. Dzięki ustawionym opcjom kupujemy materiały luzem i jesteśmy w stanie uzyskać oszczędności od naszych dostawców, które możemy przekazać Państwu. Konsekwentnie korzystamy z tych samych zawodów w całym naszym dziale, co oznacza, że \u200b\u200bmają one nasze plany i procesy sprowadzające się do nauki. Znają produkt, co oznacza mniejsze prawdopodobieństwo popełnienia błędów i mniejsze prawdopodobieństwo przeoczenia rzeczy. Naszym sercem jest przystępność cenowa, ponieważ rozumiemy, że nie każdy może sobie pozwolić na granit, gaz, podłogi z twardego drewna itp., więc pozwalamy Ci dostosować miesięczną opłatę i że nie finansujesz czegoś, czego możesz nie chcieć, nie potrzebujesz lub pozwalają ci dostać się do domu, na który nie byłoby cię stać w inny sposób. Dużo pracujemy z kupującym po raz pierwszy i chcemy zapewnić najlepszą jakość za najlepszą cenę. Rozpoczynamy nasze domy od modelu podstawowego i pozwalamy Ci dostosować go tak, jak chcesz (dodając granit, gaz, drewno liściaste, kominek itp.), A robiąc to, pozwalamy Ci wybrać, czy chcesz zapłacić 90 USD, czy 101 USD za stopę kwadratową czy cokolwiek to może być. Mogę powiedzieć, że w północno-zachodnim Arkansas jesteśmy najlepszą wartością i pokazami jakości. Konsekwentnie ściągam konkursy i faktycznie mam innego budowniczego w tej samej społeczności, w której sprzedaję. Nasze domy w tej społeczności za jednopiętrowy kosztują około 88-95 USD, a domy dwupiętrowe kosztują średnio 78-86 USD. Dwie kondygnacje są bardziej opłacalne, ponieważ powierzchnia kwadratowa rośnie, a nie wychodzi, więc jest mniej betonu, co jest jedną z najdroższych części procesu budowy domu. Ten inny budowniczy konsekwentnie sprzedaje swoje domy za 101-105 USD za stopę kwadratową i używa dokładnie tych samych materiałów, co my. Różnica? Tak, granit i twarde drewno oraz szafy gazowe i niestandardowe są standardem, nie masz wyboru. Czy wolałbyś mieć opcję tańszego domu, jeśli nie chcesz granitu? A może wolisz mieć dywan? Budujemy na 5 różnych rynkach w 4 stanach i jesteśmy w 61. roku naszej działalności. Chętnie spotkam się z Tobą i poprowadzę Cię przez społeczność i pokażę Ci nasze domy (na wszystkich etapach budowy), w których możesz zobaczyć produkt i jakość naszych domów. Jestem w naszej społeczności Dixieland Crossing tutaj w północno-zachodnim Arkansas. Możesz sprawdzić naszą stronę internetową, aby uzyskać inne informacje pod adresem www.rauschcoleman.com']
# ['Powodem, dla którego domy Rausch Colemana są generalnie tańsze, jest to, że są one sprzedawcą masowym. Ich społeczności mają zwykle tylko 5 do 7 opcji planu piętra. Dostają wyjątkowe oferty na swoje materiały ze względu na ilość zakupionego materiału. Jeśli chodzi o liczby, sprowadzają to do nauki. Jeśli chodzi o jakość ich domów, nie mogę na to odpowiedzieć. Nigdy nie byłem w jednym ani nie znałem nikogo, kto go kupił.']
# ['Nie tylko mają dużą objętość, ale także większość materiałów wykończeniowych jest bardzo prosta. Na przykład oprawy oświetleniowe, większość budowniczych umieszcza wentylatory sufitowe we wszystkich sypialniach (75 USD), podczas gdy Rausch Coleman używa montażu podtynkowego (15 USD) w zapasowych sypialniach. Podobnie jak w przypadku podłóg, używają winylowej deski, gdzie większość budowniczych używa drewna. Może to kosztować 1 stopę kwadratową lub więcej. Szafki, dywan, płytki, blaty, krany, wszystko jedno. To wszystko są kosmetyki i możesz zaoszczędzić mnóstwo pieniędzy podczas budowy, robiąc to i nadal budując wysokiej jakości dom. Rausch Coleman buduje wysokiej jakości dom w przystępnej cenie, utrzymując podstawowe kosmetyki.']
# ['Są tanie, ponieważ są wykonane z taniego materiału. Wszystkie domy w moim dodatku to Ruasch Coleman i wiele z nich ma problemy (Oklahoma). Kilku ma około 5 lat i musiało już zdobyć nowe dachy. Na naszej sąsiedniej stronie FB pojawiły się skargi na system wodno-kanalizacyjny i powodzie na podwórkach, które nie zostały odpowiednio wyrównane po osiedleniu się gruntu. Wiem, że żałuję zakupu. Dostajesz to, za co płacisz.']
# ['Zbadaj firmę, to wszystko, co mogę powiedzieć, że ta firma ma okropne recenzje. Pokazują na swojej stronie na Facebooku świetne recenzje, ale jeśli naprawdę przejrzysz wszystkie recenzje, wysokie oceny pochodzą od byłych i obecnych pracowników. Wszystkie inne recenzje od rzeczywistych właścicieli domów są złe. Składają wiele fałszywych obietnic i budują bardzo tanie domy, które nie przetrwają bez kilku kosztownych problemów w najbliższej przyszłości. Większość ludzi, którzy kupują jeden ze swoich domów, sprzedaje go w ciągu kilku lat, ponieważ zaczynają mieć tak wiele problemów. Mają zewnętrznych dostawców wykonujących całą pracę i nie sprawiają, że ci dostawcy są bardzo odpowiedzialni. Wiem, że przez kilka lat byłem menadżerem w Rausch. NIE ZBLIŻAJ SIĘ!']
# ['Mieszkam w moim RC Home od 2008 roku i mam ZERO PROBLEMÓW! Jesteśmy w trakcie budowy kolejnego domu RC w innej społeczności. Jedyne, co zrobiłem, to wymiana dachu TYLKO z powodu bardzo silnej burzy gradowej (wielkości baseballu), która przeszła przez OKC. Moja mama również kupiła dom RC w 2007 roku i nie miała żadnych problemów. To, co kupujący muszą zrobić, to być zaangażowanym przez cały czas przed, w trakcie i po budowie. Zrób dużo zdjęć całego procesu, jeśli możesz. Codziennie korzystaliśmy z naszej kompilacji (nie mieszkaliśmy tak daleko), ale jeśli możesz skorzystać ze swojej kompilacji przynajmniej raz w tygodniu, to pomaga. Podczas mojej inspekcji w listwie przypodłogowej pojawiła się rysa włoskowata i została ona natychmiast naprawiona. Jeśli masz dobrego inspektora i przedstawiciela handlowego, któremu naprawdę zależy, wszystko będzie dobrze i pokochasz swój dom. Dobra robota DOMY RC!']
# ['Wszedłem dziś po południu do nowego domu mojej siostry, Rauscha Colemana, aby pomóc jej się wprowadzić i powiedziałem jej, żeby założyła drzwi do pokoju z podgrzewaczem wody w garażu, kiedy wrócą, aby zająć się ostatnimi poprawkami. Powiedziałem też i nie pozwól im zapomnieć o pomalowaniu garażu, ponieważ podczas jazdy przez jej okolicę zauważyłem, że wszyscy mieli oklejone i zabłocone garaże, ale nie ma farby. Powiedziała mi, że Rausch Coleman nie wróci, żeby robić poprawki. Powiedziałem co z tymi rzeczami?!?!!!!! Moja siostra powiedziała, że \u200b\u200bw domu nie ma drzwi do podgrzewacza wody ani malowania garażu. Mówisz poważnie?????? To tak, jakby nie zakładać osłon na gniazdka elektryczne... żartujesz, że nie ma tego w podstawowym opakowaniu. Wstydź się Raush Coleman. Twoje ceny nie są tak tanie, żeby tego nie uwzględnić. To jest to, co nazywam złą obsługą klienta i oszukiwaniem twoich klientów. Malowanie jest ohydne. Powiedzmy, że mój 9-latek mógłby wykonać lepszą pracę niż to. Lustra w jej łazienkach nie są zawieszone pośrodku i są tak oczywiste. Poszła otworzyć zmywarkę, która wyszła z otworu, ponieważ nigdy nie była zakotwiczona. Mogłabym gadać i gadać!!!!!! Nie używaj tego kreatora!!!!!!!']

# %% [markdown]
# #### Getting responses from elastic

# %%
def distort_list_to_question(distort_list_item):
  space = ' '
  full_question = ''
  for i in range(len(distort_list_item)):
    if i != len(distort_list_item) - 1:
      full_question += distort_list_item[i] + space
    else:
      full_question += distort_list_item[i]
  return full_question

# %%
distort_list_to_question(['co', 'jest', 'uważane', 'za', 'wydaotek', 'służbowy', 'w', 'podróży', 'służbowej'])
# Out:
# 'co jest uważane za wydaotek służbowy w podróży służbowej'

# %%
results_lam_syn = {}

indexes_types = [
  "answer_with_synonyms_with_lam",
  "answer_with_synonyms_without_lam",
  "answer_without_synonyms_with_lam",
  "answer_without_synonyms_without_lam"
]
for i in indexes_types:
  results_lam_syn[i] = {}

results_lam_syn
# Out:
# {'answer_with_synonyms_with_lam': {},
#  'answer_with_synonyms_without_lam': {},
#  'answer_without_synonyms_with_lam': {},
#  'answer_without_synonyms_without_lam': {}}

# %%
for index in range(len(distort_list)):
    question = distort_list_to_question(distort_list_item=distort_list[index])
    query_with_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_with_lam": question
            }
        },
        "size": 10
    }
    query_with_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_without_lam": question
            }
        },
        "size": 10
    }
    query_without_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_with_lam": question
            }
        },
        "size": 10
    }
    query_without_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_without_lam": question
            }
        },
        "size": 10
    }

    queries_temp_list = [query_with_synonyms_with_lam,
                         query_with_synonyms_without_lam,
                         query_without_synonyms_with_lam,
                         query_without_synonyms_without_lam]


    for j in range(len(queries_temp_list)):
        response = es.search(index=index_name, body=queries_temp_list[j])
        response = response['hits']['hits']
        temp_list = []
        for i in response:
            temp_list.append(int(i['_id']))
        if len(temp_list) != 0: 
            results_lam_syn[indexes_types[j]][int(indexes_list[index])] = temp_list

# %%
import numpy as np

def calculate_dcg(documents_relevance, k):
  sum = 0
  for index in range(k):
    #need to add another + 1 because python lists starts from 0
    sum += documents_relevance[index] / np.log2(index + 1 + 1)

  return sum

def calculate_ndcg(results, query_to_corpus, k):
  ndcg_list = []
  for key, items in results.items():
    true_relevance = [1 if i in query_to_corpus[key] else 0 for i in items]
    dcg = calculate_dcg(true_relevance, len(true_relevance))
    idcg = calculate_dcg(sorted(true_relevance, reverse=True), len(true_relevance))

    ndcg_list.append(0 if dcg == 0 else dcg / idcg)
  return np.mean(ndcg_list)

# %%
for j in range(len(results_lam_syn)):
  result = calculate_ndcg(results_lam_syn[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")
# Out:
# NDCG@10 for answer_with_synonyms_with_lam: 0.26056267798681115
# NDCG@10 for answer_with_synonyms_without_lam: 0.26056267798681115
# NDCG@10 for answer_without_synonyms_with_lam: 0.19147566890177467
# NDCG@10 for answer_without_synonyms_without_lam: 0.19147566890177467

# %% [markdown]
# # 5) Morefeus binding

# %% [markdown]
# Testing morfeusz

# %%
import morfeusz2

morfeusz = morfeusz2.Morfeusz()
morfeusz

# %%
analysis = morfeusz.analyse("próbk")
analysis
#analysis[0][2][2]
# Out:
# [(0, 1, ('próbk', 'próbk', 'ign', [], []))]

# %%
morf_results = {}

for s_i,sentence in enumerate(distort_list):
  for w_i,word in enumerate(sentence):
    try:
        result = morfeusz.analyse(word)
        if len(result) < 1 or result[0][2][2] == 'ign':
            morf_results[s_i] = (word, s_i, w_i)
    except IndexError as e:
        pass

# %%
len(morf_results)
# Out:
# 5884

# %%
#word, sentence_id, word_id
morf_results[8]
# Out:
# ('jaq', 8, 0)

# %% [markdown]
# # 6) Calculating Levenshtein distance

# %% [markdown]
# levenshtein from geeks for geeks

# %%
import math

# %%
# Python program for the above approach
def levenshtein_two_matrix_rows(str1, str2):
    # Get the lengths of the input strings
    m = len(str1)
    n = len(str2)
 
    # Initialize two rows for dynamic programming
    prev_row = [j for j in range(n + 1)]
    curr_row = [0] * (n + 1)
 
    # Dynamic programming to fill the matrix
    for i in range(1, m + 1):
        # Initialize the first element of the current row
        curr_row[0] = i
 
        for j in range(1, n + 1):
            if str1[i - 1] == str2[j - 1]:
                # Characters match, no operation needed
                curr_row[j] = prev_row[j - 1]
            else:
                # Choose the minimum cost operation
                curr_row[j] = 1 + min(
                    curr_row[j - 1],  # Insert
                    prev_row[j],      # Remove
                    prev_row[j - 1]    # Replace
                )
 
        # Update the previous row with the current row
        prev_row = curr_row.copy()
 
    # The final element in the last row contains the Levenshtein distance
    return curr_row[n]

# %%
return_list_laven = {}

for key, word in morf_results.items():
  min_ = math.inf
  word_ = ''
  for prop_word in merged_frequency.most_common(50):
    variable = levenshtein_two_matrix_rows(word[0], prop_word[0])
    if min_ > variable:
      min_ = variable
      word_ = prop_word[0]
  return_list_laven[key] = (word[0],word_,correct_list[word[1]],word[1])

#wrong, proposed, correct, #word_id
return_list_laven[8]
# Out:
# ('jaq', 'jak', 'jak', 8)

# %%
morf_results[8]
# Out:
# ('jaq', 8, 0)

# %% [markdown]
# #### Calculating ndcg for lavenstein

# %%
results_lam_syn_laven = {}

indexes_types = [
  "answer_with_synonyms_with_lam",
  "answer_with_synonyms_without_lam",
  "answer_without_synonyms_with_lam",
  "answer_without_synonyms_without_lam"
]
for i in indexes_types:
  results_lam_syn_laven[i] = {}


for index in range(len(distort_list)):
    #If lavenstein changed word
    if index in return_list_laven:
        wrong, proposed, correct, _ = return_list_laven[index]
        _ ,_ , word_index = morf_results[index]
        distort_list[index][word_index] = proposed
    question = distort_list_to_question(distort_list_item=distort_list[index])
    query_with_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_with_lam": question
            }
        },
        "size": 10
    }
    query_with_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_without_lam": question
            }
        },
        "size": 10
    }
    query_without_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_with_lam": question
            }
        },
        "size": 10
    }
    query_without_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_without_lam": question
            }
        },
        "size": 10
    }

    queries_temp_list = [query_with_synonyms_with_lam,
                         query_with_synonyms_without_lam,
                         query_without_synonyms_with_lam,
                         query_without_synonyms_without_lam]


    for j in range(len(queries_temp_list)):
        response = es.search(index=index_name, body=queries_temp_list[j])
        response = response['hits']['hits']
        temp_list = []
        for i in response:
            temp_list.append(int(i['_id']))
        if len(temp_list) != 0: 
            results_lam_syn_laven[indexes_types[j]][int(indexes_list[index])] = temp_list

# %%
print("NDCG for lavenstein")
for j in range(len(results_lam_syn_laven)):
  result = calculate_ndcg(results_lam_syn_laven[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")
# Out:
# NDCG for lavenstein
# NDCG@10 for answer_with_synonyms_with_lam: 0.2313633181296635
# NDCG@10 for answer_with_synonyms_without_lam: 0.2313633181296635
# NDCG@10 for answer_without_synonyms_with_lam: 0.17158514249007845
# NDCG@10 for answer_without_synonyms_without_lam: 0.17158514249007845

# %% [markdown]
# # 6) Elastic fuzzy search

# %%
results_lam_syn_fuzzy = {}

indexes_types = [
  "answer_with_synonyms_with_lam",
  "answer_with_synonyms_without_lam",
  "answer_without_synonyms_with_lam",
  "answer_without_synonyms_without_lam"
]
for i in indexes_types:
  results_lam_syn_fuzzy[i] = {}


for index in range(len(distort_list)):  
    question = distort_list_to_question(distort_list_item=distort_list[index])
    query_with_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_with_lam": {
                "query": question,
                "fuzziness": "AUTO"
            }
            }
        },
        "size": 10
    }
    query_with_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_with_synonyms_without_lam": {
                "query": question,
                "fuzziness": "AUTO"
            }
            }
        },
        "size": 10
    }
    query_without_synonyms_with_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_with_lam": {
                "query": question,
                "fuzziness": "AUTO"
            }
            }
        },
        "size": 10
    }
    query_without_synonyms_without_lam = {
        "query": {
            "match": {
                "answer_without_synonyms_without_lam": {
                "query": question,
                "fuzziness": "AUTO"
            }
            }
        },
        "size": 10
    }

    queries_temp_list = [query_with_synonyms_with_lam,
                         query_with_synonyms_without_lam,
                         query_without_synonyms_with_lam,
                         query_without_synonyms_without_lam]


    for j in range(len(queries_temp_list)):
        response = es.search(index=index_name, body=queries_temp_list[j])
        response = response['hits']['hits']
        temp_list = []
        for i in response:
            temp_list.append(int(i['_id']))
        if len(temp_list) != 0: 
            results_lam_syn_fuzzy[indexes_types[j]][int(indexes_list[index])] = temp_list

# %%
print("NDCG for fuzzy")
for j in range(len(results_lam_syn_fuzzy)):
  result = calculate_ndcg(results_lam_syn_fuzzy[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")
# Out:
# NDCG for fuzzy
# NDCG@10 for answer_with_synonyms_with_lam: 0.20526584646555857
# NDCG@10 for answer_with_synonyms_without_lam: 0.20540305584428833
# NDCG@10 for answer_without_synonyms_with_lam: 0.16876960250137804
# NDCG@10 for answer_without_synonyms_without_lam: 0.1688763937821283

# %% [markdown]
# # 7) LLM

# %% [markdown]
# Chat gpt (free use)

# %%
sentences_llm = []

for list_ in distort_list[:30]:
  sentence = ''
  for word in list_:
    sentence = sentence + word + ' '
  sentences_llm.append(sentence)

for sentence in sentences_llm:
  print(sentence)
# Out:
# co jest uważane za wydatek służbowy ó podróży służbowej
# wydatki służbowe ubezpieczenie samochodu podlegające odliczeniu za wypadek który wydarzył się pvodczas podróży służbowej
# rozpoczęcie noweęo biznesu online
# dzień roboczy i termin płatności rachyunków
# nowy właśczciel firmy jak działają podatki dla firmy i osoby fizycznej
# hbby kontra biznes
# czeki osobiste zamiąast firmowych
# zy amerykański kodeks podatkowy wymaga aby właściciele małych firm liczyli zakupy biznesowe jako dochód osobisty
# jak mogę zarejestrować firmę w wielkiej brytanii bez podafwania adresu firmy
# czym są podsitawy biznesowe
# strata na inwestycjach biznesowych  poprzedniego roku
# jak mogę oszacować podatki biznesowe opłaty źza zgłoszenie dla firmy która ma 0 usd dochodu
# czy zakup samochodu dla firmy za pomocą kredytu biznesowego zostałby uoznany za wydatek biznesowy
# odliczanie strat biznesowych z ostatnich lhat nieudokumentowanych
# c0 udziału w biznesie
# odbieranie wydatków służbowych z osobistej krty kredytowej
# używanie czeku biznesowego do płatności ż handlu detalicznym
# podatek przy zakładaniu firmy w pełnym ymiarze czasu pracy
# czy mogę spłacić saldo oarty kredytowej aby zwolnić dostępny kredyt
# powolne rozpoczynanie działalnośmi pobocznej
# dlaczego spieniężanie czeków jest legalną dzlałalnością
# czy biznes to jedyny sposób nła zostanie milionerem
# wycenianie małej firmy zw którą warto zainwestować
# rozpoczęcie dużego biznesu x niezbyt dużymi dochodami
# wymagania dotyczące rozlicania podatków biznesowych
# ira ado pracy i mojej firmy
# dosradztwo w zakresie transferu pieniędzy
# jak przenieść leqasing samochodu osobistego do leasingu samochodu biznesowego
# korepetycje z zarządzania płacami biznefowymi
# czy jako właściciel małej firmy powinienemm płacić podatki z mojego osobistego lub firmowego konta czekowego

# %% [markdown]
# 1) Co jest uważane za wydatek służbowy w podróży służbowej?
# 2) Wydatki służbowe, takie jak ubezpieczenie samochodu, podlegają odliczeniu w przypadku wypadku, który wydarzył się podczas podróży służbowej. (wypadek, wypadku)
# 3) Rozpoczęcie nowego biznesu online.
# 4) Dzień roboczy i termin płatności rachunków.
# 5) Nowy właściciel firmy — jak działają podatki dla firmy i osoby fizycznej.
# 6) Hobby kontra biznes.
# 7) Czeki osobiste zamiast firmowych.
# 8) Czy amerykański kodeks podatkowy wymaga, aby właściciele małych firm traktowali zakupy biznesowe jako dochód osobisty?
# 9) Jak mogę zarejestrować firmę w Wielkiej Brytanii bez podawania adresu firmy?
# 10) Czym są podstawy biznesowe?
# 11) Strata na inwestycjach biznesowych z poprzedniego roku. (strata, straty)
# 12) Jak mogę oszacować podatki biznesowe i opłaty za zgłoszenie firmy, która ma 0 USD dochodu?
# 13) Czy zakup samochodu dla firmy za pomocą kredytu biznesowego zostałby uznany za wydatek biznesowy?
# 14) Odliczanie strat biznesowych z ostatnich lat, nieudokumentowanych.
# 15) Co to jest udział w biznesie?
# 16) Odbieranie wydatków służbowych z osobistej karty kredytowej.
# 17) Używanie czeku biznesowego do płatności w handlu detalicznym.
# 18) Podatek przy zakładaniu firmy w pełnym wymiarze czasu pracy.
# 19) Czy mogę spłacić saldo karty kredytowej, aby zwolnić dostępny kredyt?
# 20) Powolne rozpoczynanie działalności pobocznej.
# 21) Dlaczego spieniężanie czeków jest legalną działalnością?
# 22) Czy biznes to jedyny sposób na zostanie milionerem?
# 23) Wycena małej firmy, w którą warto zainwestować.
# 24) Rozpoczęcie dużego biznesu z niezbyt dużymi dochodami. (niezbyt, niezbyt dużymi)
# 25) Wymagania dotyczące rozliczania podatków biznesowych.
# 26) IRA, ADO pracy i mojej firmy.
# 27) Doradztwo w zakresie transferu pieniędzy.
# 28) Jak przenieść leasing samochodu osobistego do leasingu samochodu biznesowego?
# 29) Korepetycje z zarządzania płacami biznesowymi.
# 30) Czy jako właściciel małej firmy powinienem płacić podatki z mojego osobistego czy firmowego konta czekowego?

# %% [markdown]
# # 7) Anwsers

# %% [markdown]
# Draw conclusions regarding:

# %% [markdown]
# #### The distribution of words in the corpus:

# %% [markdown]
# From what we have seen most common words are (`przyimek`, `partykuła`, `spójnik`, `zaimek` etc.). This is really reasonable as these are functional words that perform a certain role in sentences.

# %% [markdown]
# #### The performance of your method compared to ElasticSearch

# %% [markdown]
# Comparing all 3 methods results below

# %%
print("NDCG for baseline")
for j in range(len(results_lam_syn)):
  result = calculate_ndcg(results_lam_syn[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")


print("NDCG for fuzzy")
for j in range(len(results_lam_syn_fuzzy)):
  result = calculate_ndcg(results_lam_syn_fuzzy[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")

print("NDCG for lavenstein")
for j in range(len(results_lam_syn_laven)):
  result = calculate_ndcg(results_lam_syn_laven[indexes_types[j]],query_to_corpus, 10)
  print(f"NDCG@10 for {indexes_types[j]}: {result}")
# Out:
# NDCG for baseline
# NDCG@10 for answer_with_synonyms_with_lam: 0.26056267798681115
# NDCG@10 for answer_with_synonyms_without_lam: 0.26056267798681115
# NDCG@10 for answer_without_synonyms_with_lam: 0.19147566890177467
# NDCG@10 for answer_without_synonyms_without_lam: 0.19147566890177467
# NDCG for fuzzy
# NDCG@10 for answer_with_synonyms_with_lam: 0.20526584646555857
# NDCG@10 for answer_with_synonyms_without_lam: 0.20540305584428833
# NDCG@10 for answer_without_synonyms_with_lam: 0.16876960250137804
# NDCG@10 for answer_without_synonyms_without_lam: 0.1688763937821283
# NDCG for lavenstein
# NDCG@10 for answer_with_synonyms_with_lam: 0.2385672312581576
# NDCG@10 for answer_with_synonyms_without_lam: 0.2385672312581576
# NDCG@10 for answer_without_synonyms_with_lam: 0.17616065180207388
# NDCG@10 for answer_without_synonyms_without_lam: 0.17616065180207388

# %% [markdown]
# As we can see the baseline result were the best, second was lavenstein ad last elastic fuzzy. The reason for lavenstain second place can be the word change, while changing the words we onlu accounted top 500 most common words so there is a possibility that a long word with one letter taken could be replace by a short word like `sużbowy` for `że`. The fuzziness third place is quite shocking, especially that it is based on lavenstein distance. I think that because we set the value for AUTO we were not able to find proper responses.

# %% [markdown]
# #### The results provided by your method compared to ElasticSearch,

# %% [markdown]
# Comparing the result of my lavenstein method both with baseline and elastic search from lab2 we cane see a small drawback compared to lab2 with baseline results. While we compared the lavenstein with baseline comparing it with lab2 we can see a bigger drawback about 0.06.

# %% [markdown]
# #### The validity of the obtained corrections,

# %% [markdown]
# It is easy to say that our corrections were not valid, not only the score got worse compared to baseline but while implementig the method i saw changes like `sużbowy` to `że` maybe if we had operated on a larger set of words the results could be better.

# %% [markdown]
# #### Ability of an LLM to fix invalid queries

# %% [markdown]
# LLM successfully fixed all the words in sentences, although costly it is a better aprroach than using laventstein and most common words in corpus.
